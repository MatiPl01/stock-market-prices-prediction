# %% [markdown]
# # Fetching

# %% [markdown]
# ## Import useful libraries

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv

# %% [markdown]
# ## Declare constants and read the API key

# %%
load_dotenv()
API_KEY = os.getenv("FMP_API_KEY")

BASE_URL = "https://financialmodelingprep.com/api/v3"
LIMIT = 80  # Number of periods (80 quarters = 20 years)
PERIOD = "quarter"  # Fetch quarterly data
OUTPUT_DIR = "data"
OUTPUT_FILENAME = "balance_sheets_quarterly.csv"
EXCHANGE_SHORT_NAME = "WSE"  # Warsaw Stock Exchange short name

# %% [markdown]
# ## Useful functions for data fetching

# %%
def fetch_all_symbols():
    url = f"{BASE_URL}/stock/list?apikey={API_KEY}"
    response = requests.get(url)
    data = response.json()
    return data


def filter_wse_symbols(all_symbols):
    wse_symbols = [
        stock["symbol"]
        for stock in all_symbols
        if stock["exchangeShortName"] == EXCHANGE_SHORT_NAME
    ]
    return wse_symbols


def fetch_balance_sheet(symbol):
    url = f"{BASE_URL}/balance-sheet-statement/{symbol}?apikey={API_KEY}&limit={LIMIT}&period={PERIOD}"
    response = requests.get(url)
    data = response.json()
    return data


def fetch_historical_stock_prices(symbol, from_date, to_date):
    # Fetch historical prices for the exact date range of balance sheets
    url = f"{BASE_URL}/historical-price-full/{symbol}?from={from_date}&to={to_date}&apikey={API_KEY}"
    response = requests.get(url)
    data = response.json()
    if "historical" in data:
        return data["historical"]
    return []


def get_closest_price(stock_prices, date):
    # Find the closest stock price to the balance sheet date
    for price_record in stock_prices:
        if price_record["date"] <= date:
            return price_record["close"]
    return None


def create_dataframe(symbols):
    all_data = []

    for symbol in symbols:
        balance_sheet_data = fetch_balance_sheet(symbol)

        if not balance_sheet_data:
            continue

        # Get the earliest and latest dates from the balance sheet data
        balance_sheet_dates = [record["date"] for record in balance_sheet_data]
        from_date = min(balance_sheet_dates)
        to_date = max(balance_sheet_dates)

        # Fetch historical prices for the date range
        stock_prices = fetch_historical_stock_prices(symbol, from_date, to_date)

        for record in balance_sheet_data:
            date = record["date"]
            stock_price = get_closest_price(
                stock_prices, date
            )  # Find the closest price to the balance sheet date
            shares_outstanding = record.get(
                "commonStock", None
            )  # Get the number of shares outstanding

            if stock_price is not None and shares_outstanding is not None:
                # Calculate market cap as stock price * shares outstanding
                market_cap = stock_price * shares_outstanding
            else:
                market_cap = None

            record["symbol"] = symbol
            record["marketCap"] = market_cap
            all_data.append(record)

    df = pd.DataFrame(all_data)
    return df

# %% [markdown]
# ## Fetch data and create a DataFrame

# %%
all_symbols = fetch_all_symbols()
all_symbols
# Out:
# [{'symbol': 'PMGOLD.AX',
#   'name': 'Perth Mint Gold',
#   'price': 17.94,
#   'exchange': 'Australian Securities Exchange',
#   'exchangeShortName': 'ASX',
#   'type': 'etf'},
#  {'symbol': 'ANGL.TA',
#   'name': 'Salomon A. Angel Ltd.',
#   'price': 3382,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PRPD.TA',
#   'name': 'Propdo Ltd',
#   'price': 2037,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ZUR.TA',
#   'name': 'Zur Shamir Holdings Ltd',
#   'price': 613.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SPDV.TA',
#   'name': 'Speedvalue Ltd',
#   'price': 360.3,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TEDE.TA',
#   'name': 'Tedea Technological Development and Automation Ltd.',
#   'price': 632,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MEDN.TA',
#   'name': 'Mehadrin Ltd.',
#   'price': 14650,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MNIF.TA',
#   'name': 'Menif - Financial Services Ltd',
#   'price': 1317,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TIGBUR.TA',
#   'name': 'Tigbur - Temporary Professional Personnel Ltd.',
#   'price': 4621,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ORTC.TA',
#   'name': 'O.R.T. Technologies Ltd',
#   'price': 1090,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TRA.TA',
#   'name': 'Tarya Israel Ltd',
#   'price': 27,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TTAM.TA',
#   'name': 'Tiv Taam Holdings 1 Ltd.',
#   'price': 575,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PRTC.TA',
#   'name': 'Priortech Ltd',
#   'price': 15430,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'FIBIH.TA',
#   'name': 'F.I.B.I. Holdings Ltd',
#   'price': 15710,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PMVM.TA',
#   'name': 'Pomvom Ltd',
#   'price': 257,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RAVD.TA',
#   'name': 'Ravad Ltd',
#   'price': 739.6,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RTPT.TA',
#   'name': 'Ratio Petroleum Energy - Limited Partnership',
#   'price': 16.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'DLTI.TA',
#   'name': 'Delta Israel Brands Ltd',
#   'price': 6624,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SVRE.TA',
#   'name': 'SaverOne 2014 Ltd',
#   'price': 17.7,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BRAN.TA',
#   'name': 'Baran Group Ltd',
#   'price': 1225,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'DIPL.TA',
#   'name': 'Diplomat Holdings Ltd',
#   'price': 3230,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ARIN.TA',
#   'name': 'Ari Real Estate (Arena) Investment Ltd',
#   'price': 228.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SKLN.TA',
#   'name': 'Skyline Investments Inc.',
#   'price': 1470,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GNCL.TA',
#   'name': 'Gencell Ltd',
#   'price': 57.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'NTNB.TA',
#   'name': 'Netanel Menivim Ltd.',
#   'price': 199.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PEN.TA',
#   'name': 'Peninsula Group Ltd',
#   'price': 159.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'LCTX.TA',
#   'name': 'Lineage Cell Therapeutics, Inc.',
#   'price': 326.4,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AMAN.TA',
#   'name': 'Amanet Management & Systems Ltd.',
#   'price': 1665,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'STEC.TA',
#   'name': 'Shure-Tech Investments - Limited Partnership',
#   'price': 725,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'VTNA.TA',
#   'name': 'Vitania Ltd.',
#   'price': 2055,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ARDM.TA',
#   'name': 'Aerodrome Group Ltd',
#   'price': 41.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'DLEA.TA',
#   'name': 'Delek Automotive Systems Ltd.',
#   'price': 2213,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TMRP.TA',
#   'name': 'Tamar Petroleum Ltd',
#   'price': 1857,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'WILC.TA',
#   'name': 'G. Willi-Food International Ltd.',
#   'price': 3963,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GAGR.TA',
#   'name': 'Gaon Group Ltd.',
#   'price': 256,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'DANE.TA',
#   'name': 'Danel (Adir Yeoshua) Ltd',
#   'price': 33880,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'FORTY.TA',
#   'name': 'Formula Systems (1985) Ltd.',
#   'price': 28720,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AZRM.TA',
#   'name': 'Azorim-Investment, Development & Construction Co. Ltd',
#   'price': 1765,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ZNKL.TA',
#   'name': 'Zanlakol Ltd',
#   'price': 3674,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BOTI.TA',
#   'name': 'Bonei Hatichon Civil Engineering & Infrastructures Ltd.',
#   'price': 3580,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ZOOZ.TA',
#   'name': 'ZOOZ Power Ltd',
#   'price': 690,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ININ.TA',
#   'name': 'Inter Industries Plus Ltd',
#   'price': 232.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'FGAS.TA',
#   'name': 'Fire & Gas Detection Technologies Ltd',
#   'price': 1065,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BRIH.TA',
#   'name': 'Rav-Bariach (08) Industries Ltd.',
#   'price': 54.5,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'INRM.TA',
#   'name': 'Inrom Construction Industries Ltd',
#   'price': 1127,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GCT.TA',
#   'name': 'G City Ltd',
#   'price': 1276,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RLCO.TA',
#   'name': 'Ralco Agencies Ltd',
#   'price': 3198,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ISCD.TA',
#   'name': 'Isracard Ltd.',
#   'price': 1358,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CLIS.TA',
#   'name': 'Clal Insurance Enterprises Holdings Ltd.',
#   'price': 5828,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'VCTR.TA',
#   'name': 'Victory Supermarket Chain Ltd',
#   'price': 4378,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'NURI.TA',
#   'name': 'Nur Ink Innovations Ltd',
#   'price': 816,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MRIN.TA',
#   'name': 'Y.D. More Investments Ltd',
#   'price': 820.5,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RMON.TA',
#   'name': 'Rimon Consulting & Management Services Ltd.',
#   'price': 3334,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CMDR.TA',
#   'name': 'Computer Direct Group Ltd.',
#   'price': 26150,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PRKM.TA',
#   'name': 'Parkomat International Ltd',
#   'price': 405,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RVL.TA',
#   'name': 'Raval ACS Ltd.',
#   'price': 195.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'INCR.TA',
#   'name': 'InterCure Ltd.',
#   'price': 750,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ELRN.TA',
#   'name': 'Elron Ventures Ltd',
#   'price': 439.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RTLS.TA',
#   'name': 'Retailors Ltd',
#   'price': 6795,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ALBA.TA',
#   'name': 'Albaad Massuot Yitzhak Ltd',
#   'price': 1388,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MTRX.TA',
#   'name': 'Matrix IT Ltd.',
#   'price': 7214,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ASHO.TA',
#   'name': 'Ashot Ashkelon Industries Ltd.',
#   'price': 3560,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SHGR.TA',
#   'name': 'Shagrir Group Vehicle Services Ltd',
#   'price': 874,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CRML.TA',
#   'name': 'Carmel Corp Ltd.',
#   'price': 1680,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'KNFM.TA',
#   'name': 'Knafaim Holdings Ltd.',
#   'price': 1076,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MSVT.TA',
#   'name': 'Massivit 3D Printing Technologies Ltd',
#   'price': 139.7,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ORBI.TA',
#   'name': 'Orbit Technologies Ltd',
#   'price': 2270,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'HGG.TA',
#   'name': 'Hagag Group Real Estate Entrepreneurship Ltd',
#   'price': 1599,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'NISA.TA',
#   'name': 'Nissan Medical Industries Ltd',
#   'price': 1397,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'EMDV.TA',
#   'name': 'Emilia Development (O.F.G) Ltd.',
#   'price': 2108,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RPAC.TA',
#   'name': 'Rapac Communication & Infrastructure Ltd',
#   'price': 2518,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'OPAL.TA',
#   'name': 'Opal Balance Investments Ltd',
#   'price': 173,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BCOM.TA',
#   'name': 'B Communications Ltd',
#   'price': 1157,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'NTML.TA',
#   'name': 'Neto Malinda Trading Ltd.',
#   'price': 6350,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CLAB.TA',
#   'name': 'C-Lab Ltd',
#   'price': 941.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ELCRE.TA',
#   'name': 'Electra Real Estate Ltd.',
#   'price': 3985,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MSLA.TA',
#   'name': 'Maslavi Construction Company Ltd',
#   'price': 1314,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PRMG.TA',
#   'name': 'Primotec Group Ltd',
#   'price': 1144,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GOLF.TA',
#   'name': 'Golf & Co Group Ltd',
#   'price': 463.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'NXSN.TA',
#   'name': 'NextVison Stabilized Systems, Ltd.',
#   'price': 4345,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ATRY.TA',
#   'name': 'Atreyu Capital Markets Ltd',
#   'price': 5760,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ARD.TA',
#   'name': 'Arad Ltd.',
#   'price': 4713,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PLUR.TA',
#   'name': 'Pluri Inc.',
#   'price': 1934,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'FOX.TA',
#   'name': 'Fox-Wizel Ltd.',
#   'price': 27500,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ELWS.TA',
#   'name': 'Electreon Wireless Ltd',
#   'price': 17830,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'IDIN.TA',
#   'name': 'I.D.I. Insurance Company Ltd.',
#   'price': 12100,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AFPR.TA',
#   'name': 'AFI Properties Ltd',
#   'price': 16940,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CAST.TA',
#   'name': 'Castro Model Ltd.',
#   'price': 7482,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'IBIU.TA',
#   'name': 'I.B.I.- Managing & Underwriting Ltd',
#   'price': 615,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ELLO.TA',
#   'name': 'Ellomay Capital Ltd.',
#   'price': 4787,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RIMO.TA',
#   'name': 'Rimoni Industries Ltd.',
#   'price': 4665,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SANO1.TA',
#   'name': "Sano Bruno's Enterprises Ltd",
#   'price': 29870,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CGEN.TA',
#   'name': 'Compugen Ltd.',
#   'price': 689.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AURA.TA',
#   'name': 'Aura Investments Ltd.',
#   'price': 1592,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CRSM.TA',
#   'name': 'Carasso Motors Ltd.',
#   'price': 2030,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MPP.TA',
#   'name': 'More Provident Funds Ltd',
#   'price': 464.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SMAG.TA',
#   'name': 'Smart Agro - Limited',
#   'price': 402,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MGRT.TA',
#   'name': 'Megureit Israel Ltd',
#   'price': 398.3,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ISI.TA',
#   'name': 'ImageSat International (I.S.I) Ltd',
#   'price': 1289,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ARYT.TA',
#   'name': 'Aryt Industries Ltd.',
#   'price': 487.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'DRAL.TA',
#   'name': 'Dor Alon Energy In Israel (1988) Ltd',
#   'price': 7500,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'POLY.TA',
#   'name': 'Polygon Real Estate Ltd',
#   'price': 3954,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TOEN.TA',
#   'name': 'Tomer Energy Royalties (2012) Ltd',
#   'price': 1520,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'WILK.TA',
#   'name': 'Wilk Technologies Ltd',
#   'price': 46,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'OVRS.TA',
#   'name': 'Overseas Commerce Ltd.',
#   'price': 350,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CEL.TA',
#   'name': 'Cellcom Israel Ltd.',
#   'price': 1580,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MCLL.TA',
#   'name': 'Michlol Finance Ltd',
#   'price': 635.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BIMT.TA',
#   'name': 'Bio Meat Foodtech - Limited Partnership',
#   'price': 24,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'DNYA.TA',
#   'name': 'Danya Cebus Ltd.',
#   'price': 8460,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'LSCO.TA',
#   'name': 'Lesico Ltd',
#   'price': 301,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MMHD.TA',
#   'name': 'Menora Mivtachim Holdings Ltd',
#   'price': 10370,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ISRS.TA',
#   'name': 'Isras Investment Company Ltd',
#   'price': 72700,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MRG.TA',
#   'name': 'Multi Retail Group Ltd',
#   'price': 669,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'KEN.TA',
#   'name': 'Kenon Holdings Ltd.',
#   'price': 9100,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TGI.TA',
#   'name': 'Tgi Infrastructures Ltd',
#   'price': 187,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BLRX.TA',
#   'name': 'BioLineRx Ltd.',
#   'price': 16.5,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SKBN.TA',
#   'name': 'Shikun & Binui Ltd.',
#   'price': 873.6,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MISH.TA',
#   'name': 'Mivtach Shamir Holdings Ltd',
#   'price': 16540,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RTEN.TA',
#   'name': 'Rotem Energy Mineral (REM) - Limited Partnership',
#   'price': 213.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'DRSH.TA',
#   'name': 'Dorsel Holdings Ltd',
#   'price': 1299,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MTRN.TA',
#   'name': 'Maytronics Ltd.',
#   'price': 966,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RIT1.TA',
#   'name': 'Reit 1 Ltd',
#   'price': 1479,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'YBOX.TA',
#   'name': 'Ybox Real Estate Ltd.',
#   'price': 74.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AVGD.TA',
#   'name': 'Av-Gad Holdings Ltd.',
#   'price': 1620,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MIFT.TA',
#   'name': 'Millennium Food Tech Limited Partnership',
#   'price': 42.6,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'HIPR.TA',
#   'name': 'Hiper Global Ltd.',
#   'price': 1512,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'HLAN.TA',
#   'name': 'Hilan Ltd.',
#   'price': 19370,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'OPK.TA',
#   'name': 'OPKO Health, Inc.',
#   'price': 585,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RATI.TA',
#   'name': 'Ratio Energies - Limited Partnership',
#   'price': 289.3,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'THES.TA',
#   'name': 'Thirdeye Systems Ltd',
#   'price': 509.5,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PLSN.TA',
#   'name': 'Plasson Industries Ltd',
#   'price': 13830,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ACRO.TA',
#   'name': 'Kvutzat Acro Ltd',
#   'price': 4522,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MAXO.TA',
#   'name': 'Max Stock Ltd.',
#   'price': 965,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MCMN.TA',
#   'name': 'Michman Basad Ltd',
#   'price': 16480,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BONS.TA',
#   'name': 'Bonus BioGroup Ltd.',
#   'price': 13.4,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TAYA.TA',
#   'name': 'Taya Investment Co., Ltd.',
#   'price': 5811,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'LAPD.TA',
#   'name': 'Lapidoth Capital Ltd',
#   'price': 5378,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ELAL.TA',
#   'name': 'El Al Israel Airlines Ltd.',
#   'price': 621.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MGIC.TA',
#   'name': 'Magic Software Enterprises Ltd.',
#   'price': 3909,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'HLMS.TA',
#   'name': 'Holmes Place International Ltd',
#   'price': 503.5,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ISTA.TA',
#   'name': 'Issta Lines Ltd.',
#   'price': 7133,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CANF.TA',
#   'name': 'Can-Fite BioPharma Ltd.',
#   'price': 2.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'KAFR.TA',
#   'name': 'Kafrit Industries (1993) Ltd',
#   'price': 2373,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'QNCO.TA',
#   'name': 'Y.Z. Queenco Ltd.',
#   'price': 375.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BLGO.TA',
#   'name': 'Buligo Capital Ltd',
#   'price': 782,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CDEV.TA',
#   'name': 'Cohen Development Gas & Oil Ltd.',
#   'price': 10990,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'LBRA.TA',
#   'name': 'Libra Insurance Company Ltd',
#   'price': 542.5,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ALMA.TA',
#   'name': 'Almogim Holdings Ltd',
#   'price': 829.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AMRK.TA',
#   'name': 'Amir Marketing and Investments in Agriculture Ltd',
#   'price': 2553,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ACKR.TA',
#   'name': 'Ackerstein Group Ltd',
#   'price': 512.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'DELG.TA',
#   'name': 'Delta Galil Industries Ltd.',
#   'price': 16530,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'LBTL.TA',
#   'name': 'A. Libental Holdings Ltd',
#   'price': 1276,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ALRPR.TA',
#   'name': 'Alrov Properties and Lodgings Ltd.',
#   'price': 13470,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CPIA.TA',
#   'name': 'Cipia Vision Ltd',
#   'price': 49.5,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ETGA.TA',
#   'name': 'ETGA Group Ltd',
#   'price': 1349,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MSBI.TA',
#   'name': 'Hamashbir 365 Ltd',
#   'price': 126.3,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SHNP.TA',
#   'name': 'E. Schnapp & Co. Works Ltd',
#   'price': 1200,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RMLI.TA',
#   'name': 'Rami Levi Chain Stores Hashikma Marketing 2006 Ltd',
#   'price': 21030,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PTBL.TA',
#   'name': 'Property & Building Corp. Ltd.',
#   'price': 22790,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'LEVI.TA',
#   'name': 'Meshulam Levinstein Contracting & Engineering Ltd.',
#   'price': 25250,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'KARE.TA',
#   'name': 'Kardan Real Estate Enterprise and Development Ltd',
#   'price': 462,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'DNA.TA',
#   'name': 'Dna Group (T.R.) Ltd',
#   'price': 64.6,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MTLF.TA',
#   'name': 'Matricelf Ltd',
#   'price': 383.3,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GVYM.TA',
#   'name': 'Gav-Yam Lands Corp. Ltd',
#   'price': 2999,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'EMTC-M.TA',
#   'name': 'Elbit Medical Technologies Ltd',
#   'price': 14.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TPGM.TA',
#   'name': 'TopGum Industries Ltd.',
#   'price': 678.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'LUZN.TA',
#   'name': 'Amos Luzon Development and Energy Group Ltd',
#   'price': 252,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SBEN.TA',
#   'name': 'Shikun & Binui Energy Ltd',
#   'price': 270,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'EXPO.TA',
#   'name': 'Export Investment Co. Ltd.',
#   'price': 4824,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BRMG.TA',
#   'name': 'Brimag Digital Age Ltd.',
#   'price': 1176,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'LAHAV.TA',
#   'name': 'Lahav LR Real Estate Ltd',
#   'price': 356,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MNRT.TA',
#   'name': 'Menivim - The New Reit Ltd',
#   'price': 175,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'EPIT.TA',
#   'name': 'Epitomee Medical Ltd',
#   'price': 310.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TUZA.TA',
#   'name': 'Teuza - A Fairchild Technology Venture Ltd.',
#   'price': 38.6,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TASE.TA',
#   'name': 'The Tel-Aviv Stock Exchange Ltd.',
#   'price': 3250,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AUDC.TA',
#   'name': 'AudioCodes Ltd.',
#   'price': 3605,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'POLP.TA',
#   'name': 'Polyram Plastic Industries LTD',
#   'price': 1118,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BRND.TA',
#   'name': 'Brand Group (M.G) Ltd',
#   'price': 219.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SOLR.TA',
#   'name': 'Solaer Renewable Energies Ltd',
#   'price': 3195,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ISHI.TA',
#   'name': 'Israel Shipyards Industries Ltd',
#   'price': 6460,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SRAC.TA',
#   'name': 'S.R. Accord Ltd.',
#   'price': 2811,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SHVA.TA',
#   'name': 'Automatic Bank Services Limited',
#   'price': 1395,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TDRN.TA',
#   'name': 'Tadiran Group Ltd',
#   'price': 21050,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GLTC.TA',
#   'name': 'Galileo Tech Ltd',
#   'price': 21.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ROTS.TA',
#   'name': 'Rotshtein Realestate Ltd',
#   'price': 4550,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AYAL.TA',
#   'name': 'Ayalon Insurance Company Ltd',
#   'price': 2054,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ORON.TA',
#   'name': 'Oron Group Investments & Holdings Ltd',
#   'price': 787.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BSEN.TA',
#   'name': 'Bet Shemesh Engines Holdings (1997) Ltd',
#   'price': 23940,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AVER.TA',
#   'name': 'Averbuch Formica Center Ltd.',
#   'price': 880.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SHAN.TA',
#   'name': 'Shaniv Paper Industry Ltd',
#   'price': 350.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SVRT.TA',
#   'name': 'SavorEat Ltd.',
#   'price': 407.4,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'HICN.TA',
#   'name': 'Highcon Systems Ltd.',
#   'price': 106,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ILX.TA',
#   'name': 'Ilex Medical Ltd',
#   'price': 6443,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'WLFD.TA',
#   'name': 'Willy-Food Investments Ltd',
#   'price': 1899,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ADGR.TA',
#   'name': 'Adgar Investments and Development Ltd',
#   'price': 450,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'UNCT.TA',
#   'name': 'Unicorn Technologies - Limited Partnership',
#   'price': 43.7,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BLSR.TA',
#   'name': 'Blue Square Real Estate Ltd',
#   'price': 27270,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GSFI.TA',
#   'name': 'Gan Shmuel Foods Ltd.',
#   'price': 3519,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BLRN.TA',
#   'name': 'BladeRanger Ltd',
#   'price': 55.7,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'HAMAT.TA',
#   'name': 'Hamat Group Ltd.',
#   'price': 1181,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MNIN.TA',
#   'name': 'Mendelson Infrastructures & Industries Ltd.',
#   'price': 872.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TOPS.TA',
#   'name': 'Top Ramdor Systems & Computers Co. (1990) Ltd',
#   'price': 835.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'DORL.TA',
#   'name': 'Doral Group Renewable Energy Resources Ltd',
#   'price': 1367,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SRFT.TA',
#   'name': 'Zvi Sarfati & Sons Investments & Constructions Ltd.',
#   'price': 3388,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GLBX.TA',
#   'name': 'Glassbox Ltd',
#   'price': 3783,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PMNT.TA',
#   'name': 'Payment Financial Technologies Ltd',
#   'price': 252.6,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ABRA.TA',
#   'name': 'Abra Information Technologies Ltd.',
#   'price': 251.6,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SFRN.TA',
#   'name': 'Sufrin Holdings Ltd.',
#   'price': 565.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BWAY.TA',
#   'name': 'BrainsWay Ltd.',
#   'price': 1369,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'NSTR.TA',
#   'name': 'Norstar Holdings Inc.',
#   'price': 1060,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'NXTM.TA',
#   'name': 'Nextcom Ltd.',
#   'price': 610.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SNEL.TA',
#   'name': 'Synel M.L.L Payway Ltd',
#   'price': 1413,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'UNIT.TA',
#   'name': 'Unitronics (1989) (RG) Ltd',
#   'price': 2900,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'LEOF.TA',
#   'name': 'Lewinsky-Ofer Ltd.',
#   'price': 225.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CFX.TA',
#   'name': 'Cofix Group Ltd',
#   'price': 323.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CBI.TA',
#   'name': 'Clal Biotechnology Industries Ltd.',
#   'price': 38.7,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PTNR.TA',
#   'name': 'Partner Communications Company Ltd.',
#   'price': 1589,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MDIN.TA',
#   'name': 'Modiin Energy-Limited Partnership',
#   'price': 168.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ISRA.TA',
#   'name': 'Isramco Negev 2 Limited Partnership',
#   'price': 151.3,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ELCP.TA',
#   'name': 'ELECTRA POWER (2019) LTD',
#   'price': 2082,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ZMH.TA',
#   'name': 'Z.M.H Hammerman Ltd',
#   'price': 2750,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ORL.TA',
#   'name': 'Oil Refineries Ltd.',
#   'price': 92,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AUGN.TA',
#   'name': 'Augwind Energy Tech Storage Ltd',
#   'price': 190.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BVC.TA',
#   'name': 'BATM Advanced Communications Ltd.',
#   'price': 101.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TURB.TA',
#   'name': 'Turbogen Ltd',
#   'price': 634.4,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'NAWI.TA',
#   'name': 'Nawi Brothers Group Ltd',
#   'price': 2885,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'QLTU.TA',
#   'name': 'Qualitau Ltd',
#   'price': 15770,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GKL.TA',
#   'name': 'Global Knafaim Leasing Ltd',
#   'price': 57.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AFHL.TA',
#   'name': 'Afcon Holdings Ltd',
#   'price': 9147,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ELMR.TA',
#   'name': 'El-Mor Electric Installation & Services (1986) Ltd.',
#   'price': 1013,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'STG.TA',
#   'name': 'STG International Ltd.',
#   'price': 3740,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SCC.TA',
#   'name': 'Space-Communication Ltd',
#   'price': 31.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'APLP.TA',
#   'name': 'Apollo Power Ltd',
#   'price': 530.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ISRO.TA',
#   'name': 'Isrotel Ltd.',
#   'price': 7328,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RANI.TA',
#   'name': 'Rani Zim Shopping Centers Ltd',
#   'price': 276.3,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BVGG.TA',
#   'name': 'Bait Vegag Real Estate Development Ltd',
#   'price': 650,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GEFR.TA',
#   'name': 'Geffen Residence & Renewal Ltd',
#   'price': 60,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PZOL.TA',
#   'name': 'Paz Oil Company Ltd.',
#   'price': 38510,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GNGR.TA',
#   'name': 'Ginegar Plastic Products Ltd.',
#   'price': 979,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ELSPC.TA',
#   'name': 'Elspec Engineering Ltd',
#   'price': 543.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ENDY.TA',
#   'name': 'Endymed Ltd',
#   'price': 262,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ALAR.TA',
#   'name': 'Alarum Technologies Ltd.',
#   'price': 388,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SNCM.TA',
#   'name': 'Suny Cellular Communication Ltd',
#   'price': 100.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PRSK.TA',
#   'name': 'Prashkovsky Investments and Construction Ltd.',
#   'price': 8249,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SPNTC.TA',
#   'name': 'N.R. Spuntech Industries Ltd.',
#   'price': 414.6,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'RTSN.TA',
#   'name': 'Rotem Shani Entrepreneurship and Investment Ltd.',
#   'price': 2425,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TRX.TA',
#   'name': 'Terminal X Online Ltd.',
#   'price': 317,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BUFT.TA',
#   'name': 'Buff Technologies Ltd.',
#   'price': 1305,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SEMG.TA',
#   'name': 'Seach Medical Group Ltd',
#   'price': 197.4,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PTCH.TA',
#   'name': 'Israel Petrochemical Enterprises Ltd.',
#   'price': 189,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SCDX.TA',
#   'name': 'Scodix Ltd.',
#   'price': 285,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'FRSX.TA',
#   'name': 'Foresight Autonomous Holdings Ltd.',
#   'price': 9.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'HGGE.TA',
#   'name': 'Hagag Europe Development Z.F. Ltd',
#   'price': 442.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'DUNI.TA',
#   'name': 'Duniec Bros. Ltd.',
#   'price': 20200,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AVGL.TA',
#   'name': 'Avgol Industries 1953 Ltd',
#   'price': 131.6,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'CRSR.TA',
#   'name': 'Carasso Real Estate Ltd',
#   'price': 2850,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ELCO.TA',
#   'name': 'Elco Ltd.',
#   'price': 11000,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GLRS.TA',
#   'name': 'Globrands Ltd.',
#   'price': 40400,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SCOP.TA',
#   'name': 'Scope Metals Group Ltd.',
#   'price': 10550,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'EMITF-M.TA',
#   'name': 'Elbit Imaging Ltd.',
#   'price': 374.5,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PHTM.TA',
#   'name': 'Photomyne Ltd',
#   'price': 2322,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'HOD.TA',
#   'name': 'Hod Assaf Industries Ltd.',
#   'price': 3585,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AZRT.TA',
#   'name': 'Reit Azorim - Living Ltd',
#   'price': 365,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'YHNF.TA',
#   'name': 'M.Yochananof and Sons (1988) Ltd',
#   'price': 22010,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GOHO.TA',
#   'name': 'Golden House Ltd',
#   'price': 2149,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ORMP.TA',
#   'name': 'Oramed Pharmaceuticals Inc.',
#   'price': 874.3,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ISCN.TA',
#   'name': 'Israel Canada (T.R) Ltd',
#   'price': 1298,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SARN.TA',
#   'name': 'Sarine Technologies Ltd.',
#   'price': 65.3,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GPST.TA',
#   'name': 'Group Psagot for Finance and Investments Ltd',
#   'price': 22.4,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'AFRE.TA',
#   'name': 'Africa Israel Residences Ltd',
#   'price': 23300,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ILDR.TA',
#   'name': 'Israel Land Development - Urban Renewal Ltd',
#   'price': 730,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GILT.TA',
#   'name': 'Gilat Satellite Networks Ltd.',
#   'price': 1658,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ICON.TA',
#   'name': 'iCon Group Ltd',
#   'price': 399.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ENLV.TA',
#   'name': 'Enlivex Therapeutics Ltd.',
#   'price': 456,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ARAN.TA',
#   'name': 'Aran Research & Development (1982) Ltd.',
#   'price': 1885,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TLSY.TA',
#   'name': 'Telsys Ltd.',
#   'price': 16760,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BKRY.TA',
#   'name': 'Bikurey Hasade (Holdings) Ltd',
#   'price': 304,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'NVPT.TA',
#   'name': 'Navitas Petroleum, Limited Partnership',
#   'price': 5505,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TECT.TA',
#   'name': 'Tectona Ltd',
#   'price': 79.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ALLT.TA',
#   'name': 'Allot Ltd.',
#   'price': 1136,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BKFR.TA',
#   'name': 'Bait Bakfar Ltd',
#   'price': 1134,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'KMDA.TA',
#   'name': 'Kamada Ltd.',
#   'price': 2009,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SNFL.TA',
#   'name': 'Sunflower Sustainable Investments Ltd',
#   'price': 526.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'KLIL.TA',
#   'name': 'Klil Industries Ltd',
#   'price': 19270,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MDPR.TA',
#   'name': 'Medipower (Overseas) Public Co. Limited',
#   'price': 539.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ECP.TA',
#   'name': 'Electra Consumer Products (1970) Ltd',
#   'price': 6877,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ACCL.TA',
#   'name': 'Accel Solutions Group Ltd',
#   'price': 105.2,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ALUMA.TA',
#   'name': 'Aluma Infrastructure Fund (2020) Ltd',
#   'price': 34.5,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'trust'},
#  {'symbol': 'ALMD.TA',
#   'name': 'Allmed Solutions Ltd',
#   'price': 42,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GOSS.TA',
#   'name': 'G1 Secure Solutions Ltd',
#   'price': 484.6,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GLTL.TA',
#   'name': 'Gilat Telecom Global Ltd',
#   'price': 55.9,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GIVO.TA',
#   'name': 'Givot Olam Oil Exploration-Limited Partnership(1993)',
#   'price': 24.8,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'PNRG.TA',
#   'name': 'Phinergy Ltd.',
#   'price': 228,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'FBRT.TA',
#   'name': 'FMS Enterprises Migun Ltd.',
#   'price': 12060,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ISRG.TA',
#   'name': 'Israir Group Ltd',
#   'price': 139.3,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ARAD.TA',
#   'name': 'Arad Investment & Industrial Development Ltd.',
#   'price': 8570,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SOFW.TA',
#   'name': 'SofWave Medical Ltd.',
#   'price': 1650,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'VRDS.TA',
#   'name': 'Veridis Environment Ltd',
#   'price': 1994,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TNDO.TA',
#   'name': 'Tondo Smart Ltd',
#   'price': 416.1,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GOLD.TA',
#   'name': 'The Gold Bond Group Ltd.',
#   'price': 12850,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'HMGS.TA',
#   'name': 'HomeBiogas Ltd',
#   'price': 102.7,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'GMLA.TA',
#   'name': 'Gamla Harel Residential Real Estate Ltd',
#   'price': 607.3,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'BIRM.TA',
#   'name': 'Birman Wood & Hardware Ltd',
#   'price': 861,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'EVGN.TA',
#   'name': 'Evogene Ltd.',
#   'price': 1119,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ONE.TA',
#   'name': 'One Software Technologies Ltd',
#   'price': 4860,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'TGTR.TA',
#   'name': 'Together Pharma Ltd',
#   'price': 419,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'MLTM.TA',
#   'name': 'Malam - Team Ltd',
#   'price': 5171,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'NFTA.TA',
#   'name': 'Naphtha Israel Petroleum Corp. Ltd.',
#   'price': 2170,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'SLARL.TA',
#   'name': 'Sella Capital Real Estate Ltd.',
#   'price': 729,
#   'exchange': 'Tel Aviv',
#   'exchangeShortName': 'TLV',
#   'type': 'stock'},
#  {'symbol': 'ALTF.TA',
#   'name': 'Altshuler Shaham Finance Ltd',
# ...
#   'price': 24.81,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WOBDX',
#   'name': 'JPMorgan Core Bond Fund',
#   'price': 10.55,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WFEMX',
#   'name': 'WCM Focused Emerging Markets Fund - Investor Class',
#   'price': 13.51,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VTMSX',
#   'name': 'Vanguard Tax Managed Small Cap Fund',
#   'price': 89.54,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WMBLX',
#   'name': 'WesMark Balanced Fund',
#   'price': 14.05,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VWELX',
#   'name': 'Vanguard Wellington Fund',
#   'price': 44.76,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WBGSX',
#   'name': 'Wm. Blair Funds Growth Fund Cl N',
#   'price': 10.64,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WMGYX',
#   'name': 'Delaware Ivy Mid Cap Growth Fund',
#   'price': 27.96,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VTIAX',
#   'name': 'Vanguard Total International Stock Index Fd Admiral',
#   'price': 32.84,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VUSTX',
#   'name': 'Vanguard Long-Term Treasury Fund',
#   'price': 8.85,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VWEAX',
#   'name': 'Vanguard High-Yield Corporate Fund Admiral Shares',
#   'price': 5.49,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VWESX',
#   'name': 'Vanguard Long-Term Investment Grade Fund Investor Shrs',
#   'price': 8.18,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WHGSX',
#   'name': 'Westwood Quality SmallCap Fund Institutional Class',
#   'price': 20.98,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VTCAX',
#   'name': 'Vanguard Communication Services Index Fund',
#   'price': 68.22,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VTRIX',
#   'name': 'Vanguard International Value Fund Investor Shares',
#   'price': 42.17,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VWAHX',
#   'name': 'Vanguard High-Yield Tax-Exempt Fund',
#   'price': 10.85,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WEIMX',
#   'name': 'TETON Westwood Mighty Mites Class Institutional',
#   'price': 15.66,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WFIVX',
#   'name': 'Wilshire 5000 Index Fund Investment Class',
#   'price': 30.81,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WWWEX',
#   'name': 'Kinetics The Global Fund',
#   'price': 12.32,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WWWFX',
#   'name': 'Kinetics Funds, The Internet Fund',
#   'price': 73.78,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WMBDX',
#   'name': 'WesMark Government Bond Fund',
#   'price': 8.09,
#   'exchange': 'Other OTC',
#   'exchangeShortName': 'PNK',
#   'type': 'trust'},
#  {'symbol': 'VTINX',
#   'name': 'Vanguard Target Retirement Income Fund',
#   'price': 13.62,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VUSUX',
#   'name': 'Vanguard Long-Term Treasury Fd Admiral Shs',
#   'price': 8.85,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VTBNX',
#   'name': 'Vanguard Total Bond Market II Idx I',
#   'price': 9.76,
#   'exchange': 'Nasdaq',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VWEHX',
#   'name': 'Vanguard High Yield Corporate Fund',
#   'price': 5.49,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VTMFX',
#   'name': 'Vanguard Tax-Managed Balanced Fund Admiral Shares',
#   'price': 43.87,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VTMNX',
#   'name': 'Vanguard Developed Markets Index Fund Institutional Shares',
#   'price': 16.21,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WAGTX',
#   'name': 'Seven Canyons World Innovators Fund Investor Class',
#   'price': 13.56,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WMICX',
#   'name': 'Wasatch Micro Cap Fund',
#   'price': 7.44,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VWUAX',
#   'name': 'Vanguard U.S. Growth Fund Admiral Shares',
#   'price': 166.8,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'WVALX',
#   'name': 'Value Fund - Investor Class',
#   'price': 56.52,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VUIAX',
#   'name': 'Vanguard Utilities Index Fund Admiral Shs',
#   'price': 82.32,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VFISX',
#   'name': 'Vanguard Short-Term Treasury Fund',
#   'price': 9.97,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VMNFX',
#   'name': 'Vanguard Market Neutral Fund',
#   'price': 14.3,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VCSAX',
#   'name': 'Vanguard Consumer Staples Index Fd Admiral Shs',
#   'price': 107.51,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VBMPX',
#   'name': 'Vanguard Total Bond Market Idx InstlPls',
#   'price': 9.89,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VFSTX',
#   'name': 'Vanguard Short-Term Investment Grade Fund Investor Shrs',
#   'price': 10.45,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VPADX',
#   'name': 'Vanguard Pacific Stock Index Fund Admiral Shares',
#   'price': 92.12,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VDEQX',
#   'name': 'Vanguard Diversified Equity Fund Investor Shares',
#   'price': 48.71,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'UOPIX',
#   'name': 'ProFunds UltraNASDAQ-100 Fund Investor Class',
#   'price': 90.57,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VENAX',
#   'name': 'Vanguard Energy Index Fund Admiral Shares',
#   'price': 59.83,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VIISX',
#   'name': 'Virtus KAR International Small-Mid Cap Fund',
#   'price': 19.82,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VMGMX',
#   'name': 'Vanguard Mid-Cap Growth Index Fund',
#   'price': 97.58,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VLTCX',
#   'name': 'Vanguard LT Corporate Bond Index Fund Admiral Shs',
#   'price': 21.66,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VEVFX',
#   'name': 'Vanguard Explorer Value Fund',
#   'price': 46.06,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VHCAX',
#   'name': 'Vanguard Capital Opportunity Fund',
#   'price': 192.67,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VHCOX',
#   'name': 'Vanguard Capital Opportunity Fund Investor Shares',
#   'price': 83.46,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VSCGX',
#   'name': 'Vanguard LifeStrategy Conservative Growth Fund Investor Shares',
#   'price': 21.44,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VSCIX',
#   'name': 'Vanguard Small-Cap Index Fund Institutional Shares',
#   'price': 106.46,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'UMPIX',
#   'name': 'ProFunds UltraMid Cap Fund Investor Class',
#   'price': 61.21,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VDIPX',
#   'name': 'Vanguard Developed Markets Index Fund',
#   'price': 25.34,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VEMPX',
#   'name': 'Vanguard Extended Market Index InstlPlus',
#   'price': 318.55,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VSEQX',
#   'name': 'Vanguard Horizon Funds - Vanguard Strategic Equity Fund',
#   'price': 37.24,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VFTNX',
#   'name': 'Vanguard FTSE Social Index Fund Institutional Shs',
#   'price': 36.86,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'USCBX',
#   'name': 'Victory CA Bond',
#   'price': 10.5,
#   'exchange': 'Nasdaq',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VGRLX',
#   'name': 'Vanguard Global ex-U.S. Real Estate Index Fund Admiral Shs',
#   'price': 27.05,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'USSCX',
#   'name': 'USAA Science & Technology Fund',
#   'price': 25.91,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VGSLX',
#   'name': 'Vanguard Real Estate Index Fund Admiral Shares',
#   'price': 134.58,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'USAGX',
#   'name': 'USAA Mutual Fds Tr Precious Metals and Minerals Fund',
#   'price': 19.83,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VBAIX',
#   'name': 'Vanguard Balanced Index Fund Institutional Shares',
#   'price': 48.18,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VPMCX',
#   'name': 'Vanguard PrimeCap Fund',
#   'price': 166.48,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VBINX',
#   'name': 'Vanguard Balanced Index Fund',
#   'price': 48.17,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VADDX',
#   'name': 'Invesco Equally-Weighted S&P 500 Fund',
#   'price': 76.36,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VOHIX',
#   'name': 'Vanguard Ohio Long-Term Tax-Exempt Fund',
#   'price': 11.82,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VBTIX',
#   'name': 'Vanguard Total Bond Market Index Fund',
#   'price': 9.89,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VLIFX',
#   'name': 'Value Line Mid Cap Focused Fund, Inc.',
#   'price': 35.59,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VITPX',
#   'name': 'Vanguard Institutional Total Stock Market Index Fund',
#   'price': 92.32,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VINIX',
#   'name': 'Vanguard Institutional Index Fund Institutional Shares',
#   'price': 446.05,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VMCIX',
#   'name': 'Vanguard Mid-Cap Index Fund Institutional Shares',
#   'price': 68.11,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VFLEX',
#   'name': 'First Trust Alternative Opportunities Fund',
#   'price': 26.96,
#   'exchange': 'Nasdaq',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VGELX',
#   'name': 'Vanguard Energy Fund Admiral Shares',
#   'price': 93.69,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VALIX',
#   'name': 'Value Line Capital Appreciation Fund, Inc. Investor Class',
#   'price': 11.26,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'USAWX',
#   'name': 'USAA Sustainable World Fund Shares',
#   'price': 29.97,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VINAX',
#   'name': 'Vanguard Industrials Index Fund Admiral Shares',
#   'price': 123.54,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VICEX',
#   'name': 'USA Mutuals Vice Fund Investor Class',
#   'price': 21.23,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VBIRX',
#   'name': 'Vanguard Short-Term Bond Index Fund Admiral Shares',
#   'price': 10.3,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VFWAX',
#   'name': 'Vanguard FTSE All-World ex-US Index Fd Admiral',
#   'price': 36.98,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VDADX',
#   'name': 'Vanguard Dividend Appreciation Index Fund Admiral Shs',
#   'price': 51.65,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VMGIX',
#   'name': 'Vanguard Mid-Cap Growth Index Fund Investor Shares',
#   'price': 89.13,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VMCPX',
#   'name': 'Vanguard Mid-Cap Index Fund Institutional Plus Shares',
#   'price': 335.92,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VEIRX',
#   'name': 'Vanguard Equity-Income Fund Admiral Shares',
#   'price': 91.76,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VLCAX',
#   'name': 'Vanguard Large Cap Index Fund Admiral Shs',
#   'price': 125.09,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VEXAX',
#   'name': 'Vanguard Extended Market Index Fd Admiral Shs',
#   'price': 129.09,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VFIFX',
#   'name': 'Vanguard Target Retirement 2050 Fund',
#   'price': 48.82,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VMVAX',
#   'name': 'Vanguard Mid-Cap Value Index Fd Admiral',
#   'price': 82.82,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VAIPX',
#   'name': 'Vanguard Inflation-Protected Securities Fund',
#   'price': 23.64,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'USPRX',
#   'name': 'USAA 500 Index Fund',
#   'price': 68.9,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VGSNX',
#   'name': 'Vanguard Real Estate Index Institutional',
#   'price': 20.83,
#   'exchange': 'Nasdaq',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VQNPX',
#   'name': 'Vanguard Growth and Income Fund',
#   'price': 63.06,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VBIAX',
#   'name': 'Vanguard Balanced Index Fund Admiral Shares',
#   'price': 48.17,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VITAX',
#   'name': 'Vanguard Information Technology Index Fund Admiral Shs',
#   'price': 272.89,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VFIDX',
#   'name': 'Vanguard Intermediate-Term Investment Grade Fund Admiral Shrs',
#   'price': 8.9,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VFIIX',
#   'name': 'Vanguard GNMA Fund',
#   'price': 9.49,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  {'symbol': 'VITSX',
#   'name': 'Vanguard Total Stock Market Index Fund',
#   'price': 129.67,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'trust'},
#  ...]

# %%
wse_symbols = filter_wse_symbols(all_symbols)
wse_symbols
# Out:
# ['PEO.WA',
#  'NTC.WA',
#  'ICE.WA',
#  'CDR.WA',
#  'RLP.WA',
#  'JSW.WA',
#  'KGH.WA',
#  'TPE.WA',
#  'EAT.WA',
#  'ULG.WA',
#  'PXM.WA',
#  'NNG.WA',
#  'CCC.WA',
#  'SNT.WA',
#  'AMB.WA',
#  'DNP.WA',
#  'MOC.WA',
#  'GRX.WA',
#  'DAD.WA',
#  'PUR.WA',
#  'HRS.WA',
#  'PEP.WA',
#  'EUR.WA',
#  'MDG.WA',
#  'CPS.WA',
#  'PKP.WA',
#  'KER.WA',
#  'ETFBW20TR.WA',
#  'RBW.WA',
#  'ETFBCASH.WA',
#  'ETFBW20ST.WA',
#  'ETFSP500.WA',
#  'ETFBW20LV.WA',
#  'MIL.WA',
#  '11B.WA',
#  'LBW.WA',
#  'APT.WA',
#  'MRB.WA',
#  'LPP.WA',
#  'CIG.WA',
#  'CLN.WA',
#  'CBF.WA',
#  'PTG.WA',
#  'PGE.WA',
#  'ALR.WA',
#  'PCO.WA',
#  'UNT.WA',
#  'BDX.WA',
#  'PZU.WA',
#  'PKO.WA',
#  'GPP.WA',
#  'FAB.WA',
#  'RAE.WA',
#  'BRS.WA',
#  'CLC.WA',
#  'XTB.WA',
#  'MRC.WA',
#  'GTN.WA',
#  'COG.WA',
#  'ENA.WA',
#  'ALE.WA',
#  'SKL.WA',
#  'DBC.WA',
#  'KPL.WA',
#  'GMT.WA',
#  'GIF.WA',
#  'KGN.WA',
#  'VVD.WA',
#  'CMR.WA',
#  'BBD.WA',
#  'SFG.WA',
#  'APN.WA',
#  'PLW.WA',
#  'OPN.WA',
#  'ABE.WA',
#  'MLG.WA',
#  'INC.WA',
#  'PAS.WA',
#  'VRG.WA',
#  'SNX.WA',
#  'ACG.WA',
#  'ENI.WA',
#  'OPL.WA',
#  'GRN.WA',
#  'BFT.WA',
#  'BIO.WA',
#  'AMC.WA',
#  'OTS.WA',
#  'MAB.WA',
#  'QRS.WA',
#  'CRM.WA',
#  'PCE.WA',
#  'CAV.WA',
#  'CTX.WA',
#  'WLT.WA',
#  'ART.WA',
#  'ING.WA',
#  'PCX.WA',
#  '06N.WA',
#  'MIR.WA',
#  'ATR.WA',
#  'CMP.WA',
#  'FRO.WA',
#  'MOV.WA',
#  'ENG.WA',
#  'STF.WA',
#  'TAR.WA',
#  'GOP.WA',
#  'TOR.WA',
#  'CRJ.WA',
#  'PEN.WA',
#  'MDI.WA',
#  'DCR.WA',
#  'ABS.WA',
#  'ZEP.WA',
#  'NWG.WA',
#  'MCI.WA',
#  'BNP.WA',
#  '1AT.WA',
#  'GTC.WA',
#  'MAK.WA',
#  'SGN.WA',
#  'VOX.WA',
#  'WIK.WA',
#  'MGT.WA',
#  'ZAP.WA',
#  'PBX.WA',
#  'STS.WA',
#  'MON.WA',
#  'SKA.WA',
#  'ATT.WA',
#  'LAB.WA',
#  'WPL.WA',
#  'FTE.WA',
#  'STX.WA',
#  'IDM.WA',
#  'BOS.WA',
#  'WWL.WA',
#  'SCP.WA',
#  'ARH.WA',
#  'ERB.WA',
#  'ENT.WA',
#  'DEK.WA',
#  'ELT.WA',
#  'LTX.WA',
#  'IMS.WA',
#  'MSZ.WA',
#  '3RG.WA',
#  'HMI.WA',
#  'SHO.WA',
#  'MLS.WA',
#  'SVE.WA',
#  'MSW.WA',
#  'APR.WA',
#  'BMX.WA',
#  'ZUE.WA',
#  'ASE.WA',
#  'RFK.WA',
#  'RNK.WA',
#  'ECH.WA',
#  'BCX.WA',
#  'CRI.WA',
#  'PCF.WA',
#  'ASB.WA',
#  'ETL.WA',
#  'AAT.WA',
#  'AST.WA',
#  'MNC.WA',
#  'PCR.WA',
#  'BMC.WA',
#  'BHW.WA',
#  'TRK.WA',
#  'FMG.WA',
#  'TOA.WA',
#  'SNK.WA',
#  'KSG.WA',
#  'OND.WA',
#  'PMP.WA',
#  'VRC.WA',
#  'PLZ.WA',
#  'KMP.WA',
#  'DAT.WA',
#  'AGO.WA',
#  'ZMT.WA',
#  'ATC.WA',
#  'ANR.WA',
#  'SPL.WA',
#  'CAR.WA',
#  'KTY.WA',
#  'TEN.WA',
#  'ACP.WA',
#  'NEU.WA',
#  'HUG.WA',
#  'TXT.WA',
#  'GEA.WA',
#  'GPW.WA',
#  'KRU.WA',
#  'DOM.WA',
#  'DVL.WA',
#  'LWB.WA',
#  'MBK.WA',
#  'MBR.WA',
#  'RVU.WA',
#  'PKN.WA',
#  'SLV.WA',
#  'HRP.WA',
#  'CLE.WA',
#  'VIN.WA',
#  'ETFBM40TR.WA',
#  'ETFBS80TR.WA',
#  'SEL.WA',
#  'MLK.WA',
#  'SON.WA',
#  'URT.WA',
#  'KCH.WA',
#  'MXC.WA',
#  'ETCGLDRMAU.WA',
#  'BOW.WA',
#  'ALL.WA',
#  'WTN.WA',
#  'VOT.WA',
#  'XTP.WA',
#  'FER.WA',
#  'PAT.WA',
#  'STP.WA',
#  'FON.WA',
#  'KGL.WA',
#  'ETFBNDXPL.WA',
#  'ATG.WA',
#  'BBT.WA',
#  'LSI.WA',
#  'UNI.WA',
#  'EDI.WA',
#  'ADV.WA',
#  'ATD.WA',
#  'INL.WA',
#  'ALI.WA',
#  'SKH.WA',
#  'PGV.WA',
#  'PPS.WA',
#  'VGO.WA',
#  'EMC.WA',
#  'PHR.WA',
#  'APE.WA',
#  'BCS.WA',
#  'IFI.WA',
#  'BDZ.WA',
#  'SIM.WA',
#  'MOJ.WA',
#  'DGE.WA',
#  'SPR.WA',
#  'ZRE.WA',
#  'CFI.WA',
#  'LKD.WA',
#  'IZO.WA',
#  'INK.WA',
#  'NTT.WA',
#  'ETFBSPXPL.WA',
#  'MCR.WA',
#  'AWM.WA',
#  'PRT.WA',
#  'CPR.WA',
#  'PGM.WA',
#  'ETFBTBSP.WA',
#  'LBT.WA',
#  'CDL.WA',
#  'BCM.WA',
#  'MVP.WA',
#  'TOW.WA',
#  'MFO.WA',
#  'DPL.WA',
#  'VOW.WA',
#  'NVT.WA',
#  'ODL.WA',
#  'RND.WA',
#  'BMW.WA',
#  'KRI.WA',
#  'TRR.WA',
#  'ASML.WA',
#  'NVG.WA',
#  'DIG.WA',
#  'JWW.WA',
#  'IZS.WA',
#  'RMK.WA',
#  'B24.WA',
#  'PHN.WA',
#  'PJP.WA',
#  'WXF.WA',
#  'LEN.WA',
#  'EHG.WA',
#  'KRK.WA',
#  'SEK.WA',
#  'ALG.WA',
#  'BLO.WA',
#  'RES.WA',
#  'ATS.WA',
#  'DEL.WA',
#  'SEN.WA',
#  'NXG.WA',
#  'RPC.WA',
#  'IMC.WA',
#  'PWX.WA',
#  'BIP.WA',
#  'KCI.WA',
#  'CLD.WA',
#  'ATP.WA',
#  'ACT.WA',
#  'FSG.WA',
#  'SNW.WA',
#  'NVA.WA',
#  'PRM.WA',
#  'EKP.WA',
#  'MOL.WA',
#  'ITB.WA',
#  'WIS.WA',
#  'KOM.WA',
#  'EAH.WA',
#  'YRL.WA',
#  'IZB.WA',
#  'CCE.WA',
#  'EFK.WA',
#  'SHD.WA',
#  'TRI.WA',
#  'CPA.WA',
#  'TBL.WA',
#  'PBF.WA',
#  'MEX.WA',
#  'OPM.WA',
#  'HDR.WA',
#  'XPL.WA',
#  'DTR.WA',
#  'ETFDAX.WA',
#  'DGA.WA',
#  'MSP.WA',
#  'HEL.WA',
#  'CEZ.WA',
#  'GKI.WA',
#  'MZA.WA',
#  'MUR.WA',
#  'TSG.WA',
#  'RDN.WA',
#  'KVT.WA',
#  'LES.WA',
#  'GIG.WA',
#  'IPO.WA',
#  'SAN.WA',
#  'IBS.WA',
#  'TRN.WA',
#  'ONO.WA',
#  'SFS.WA',
#  'GOB.WA',
#  'JMT.WA',
#  'TLX.WA',
#  'WAS.WA',
#  'BST.WA',
#  'DBE.WA',
#  'IPE.WA',
#  'LRQ.WA',
#  'TMR.WA',
#  'RWL.WA',
#  'INP.WA',
#  'EUC.WA',
#  'ULM.WA',
#  'FEE.WA',
#  'ENE.WA',
#  'CSR.WA',
#  'SPH.WA',
#  'OTM.WA',
#  'SVRS.WA',
#  'AGT.WA',
#  'ALV.WA',
#  'CZT.WA',
#  'OPG.WA',
#  'NTU.WA',
#  'QNT.WA',
#  'UCG.WA',
#  'ZUK.WA',
#  'IIA.WA',
#  'KPD.WA',
#  'ITX.WA',
#  'CPD.WA',
#  'PBG.WA',
#  'THG.WA',
#  'BAY.WA',
#  'SWG.WA',
#  'MAN.WA',
#  'OBL.WA',
#  'PRI.WA',
#  'MWT.WA',
#  'ZAL.WA',
#  'SHG.WA',
#  'CTS.WA',
#  'APL.WA',
#  'PSHE.WA',
#  'MBG.WA',
#  'ERG.WA',
#  'RAF.WA',
#  'MBW.WA',
#  'ENP.WA',
#  'CPL.WA',
#  '08N.WA',
#  'RNC.WA',
#  'OVO.WA',
#  'RHD.WA',
#  'PSW.WA',
#  'BKM.WA',
#  'GCN.WA',
#  'INV.WA',
#  'FMF.WA',
#  'HUGE.WA',
#  'SUW.WA',
#  'KRC.WA',
#  'PUE.WA',
#  'BRG.WA',
#  'ARR.WA',
#  'GBK.WA',
#  'VTI.WA',
#  'K2H.WA',
#  'PUN.WA',
#  'GNB.WA',
#  'LTS.WA',
#  'IMP.WA',
#  'SKT.WA',
#  'ATL.WA',
#  'ITM.WA',
#  'FFI.WA',
#  'PGN.WA',
#  'WOJ.WA',
#  'CPG.WA',
#  'VTL.WA',
#  'PMA.WA',
#  'U2K.WA',
#  'URS.WA',
#  'ZWC.WA',
#  'OPF.WA',
#  'BAH.WA',
#  'BRA.WA',
#  'STH.WA',
#  'IFR.WA',
#  'TIM.WA',
#  'CNT.WA',
#  'LVC.WA',
#  'OEX.WA',
#  'SOL.WA',
#  'EEX.WA',
#  'ASM.WA',
#  'SES.WA',
#  'CIE.WA',
#  'GLC.WA',
#  'PTH.WA',
#  'SLZ.WA',
#  'ELZ.WA',
#  'EST.WA',
#  'RWE.WA',
#  'BML.WA',
#  'AML.WA',
#  'R22.WA']

# %%
df = create_dataframe(wse_symbols)

# %%
df.head()
# Out:
#          date  symbol reportedCurrency         cik fillingDate  \
# 0  2024-06-30  PEO.WA              PLN  0000000000  2024-06-30
# 1  2024-03-31  PEO.WA              PLN  0000000000  2024-03-31
# 2  2023-12-31  PEO.WA              PLN  0000000000  2023-12-31
# 3  2023-09-30  PEO.WA              PLN  0000000000  2023-09-30
# 4  2023-06-30  PEO.WA              PLN  0000000000  2023-06-30
#
#           acceptedDate calendarYear period  cashAndCashEquivalents  \
# 0  2024-06-28 20:00:00         2024     Q2            1.552300e+10
# 1  2024-03-30 20:00:00         2024     Q1            1.691600e+10
# 2  2023-12-30 19:00:00         2023     Q4            1.473300e+10
# 3  2023-09-29 20:00:00         2023     Q3            1.131247e+10
# 4  2023-06-29 20:00:00         2023     Q2            9.912213e+09
#
#    shortTermInvestments  ...   totalEquity  \
# 0         -2.850300e+10  ...  2.822300e+10
# 1          0.000000e+00  ...  3.168300e+10
# 2          0.000000e+00  ...  3.034100e+10
# 3          0.000000e+00  ...  2.833568e+10
# 4          0.000000e+00  ...  2.596572e+10
#
#    totalLiabilitiesAndStockholdersEquity  minorityInterest  \
# 0                           3.160460e+11        12000000.0
# 1                           3.173690e+11        13000000.0
# 2                           3.057230e+11        12000000.0
# 3                           3.099348e+11        12009000.0
# 4                           2.879213e+11        11270000.0
#
#    totalLiabilitiesAndTotalEquity  totalInvestments     totalDebt  \
# 0                    3.160460e+11      4.920000e+08  1.981900e+10
# 1                    3.173690e+11      1.266490e+11  2.042600e+10
# 2                    3.057230e+11      1.198370e+11  1.858300e+10
# 3                    3.099348e+11      1.210954e+11  1.808865e+10
# 4                    2.879213e+11      1.033854e+11  1.606473e+10
#
#         netDebt  link  finalLink     marketCap
# 0  4.296000e+09                   4.401600e+10
# 1  3.510000e+09                   4.764470e+10
# 2  3.850000e+09                   3.983710e+10
# 3  6.776180e+09                   2.649635e+10
# 4  6.152515e+09                   2.908168e+10
#
# [5 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20378 entries, 0 to 20377
# Data columns (total 55 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   date                                     20378 non-null  object
#  1   symbol                                   20378 non-null  object
#  2   reportedCurrency                         20378 non-null  object
#  3   cik                                      20378 non-null  object
#  4   fillingDate                              20378 non-null  object
#  5   acceptedDate                             20146 non-null  object
#  6   calendarYear                             20378 non-null  object
#  7   period                                   20378 non-null  object
#  8   cashAndCashEquivalents                   20378 non-null  float64
#  9   shortTermInvestments                     20378 non-null  float64
#  10  cashAndShortTermInvestments              20378 non-null  float64
#  11  netReceivables                           20378 non-null  float64
#  12  inventory                                20378 non-null  float64
#  13  otherCurrentAssets                       20378 non-null  float64
#  14  totalCurrentAssets                       20378 non-null  float64
#  15  propertyPlantEquipmentNet                20378 non-null  float64
#  16  goodwill                                 20378 non-null  float64
#  17  intangibleAssets                         20378 non-null  float64
#  18  goodwillAndIntangibleAssets              20378 non-null  float64
#  19  longTermInvestments                      20378 non-null  float64
#  20  taxAssets                                20378 non-null  float64
#  21  otherNonCurrentAssets                    20378 non-null  float64
#  22  totalNonCurrentAssets                    20378 non-null  float64
#  23  otherAssets                              20378 non-null  float64
#  24  totalAssets                              20378 non-null  float64
#  25  accountPayables                          20378 non-null  float64
#  26  shortTermDebt                            20378 non-null  float64
#  27  taxPayables                              20378 non-null  float64
#  28  deferredRevenue                          20378 non-null  float64
#  29  otherCurrentLiabilities                  20378 non-null  float64
#  30  totalCurrentLiabilities                  20378 non-null  float64
#  31  longTermDebt                             20378 non-null  float64
#  32  deferredRevenueNonCurrent                20378 non-null  float64
#  33  deferredTaxLiabilitiesNonCurrent         20378 non-null  float64
#  34  otherNonCurrentLiabilities               20378 non-null  float64
#  35  totalNonCurrentLiabilities               20378 non-null  float64
#  36  otherLiabilities                         20378 non-null  float64
#  37  capitalLeaseObligations                  20378 non-null  float64
#  38  totalLiabilities                         20378 non-null  float64
#  39  preferredStock                           20378 non-null  float64
#  40  commonStock                              20378 non-null  float64
#  41  retainedEarnings                         20378 non-null  float64
#  42  accumulatedOtherComprehensiveIncomeLoss  20378 non-null  float64
#  43  othertotalStockholdersEquity             20378 non-null  float64
#  44  totalStockholdersEquity                  20378 non-null  float64
#  45  totalEquity                              20378 non-null  float64
#  46  totalLiabilitiesAndStockholdersEquity    20378 non-null  float64
#  47  minorityInterest                         20378 non-null  float64
#  48  totalLiabilitiesAndTotalEquity           20378 non-null  float64
#  49  totalInvestments                         20378 non-null  float64
#  50  totalDebt                                20378 non-null  float64
#  51  netDebt                                  20378 non-null  float64
#  52  link                                     20378 non-null  object
#  53  finalLink                                20378 non-null  object
#  54  marketCap                                18603 non-null  float64
# dtypes: float64(45), object(10)
# memory usage: 8.6+ MB

# %%
# Ensure the output directory exists
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# Save DataFrame to a CSV file in the output directory
output_path = os.path.join(OUTPUT_DIR, OUTPUT_FILENAME)
df.to_csv(output_path, index=False)

print(f"Data has been saved to {output_path}")
# Out:
# Data has been saved to data\balance_sheets_quarterly.csv
