# %% [markdown]
# # Fetching

# %% [markdown]
# ## Import useful libraries

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv

# %% [markdown]
# ## Declare constants and read the API key

# %%
load_dotenv()
API_KEY = os.getenv("FMP_API_KEY")

BASE_URL = "https://financialmodelingprep.com/api/v3"
LIMIT = 80  # Number of periods (80 quarters = 20 years)
PERIOD = "quarter"  # Fetch quarterly data
OUTPUT_DIR = "data"
OUTPUT_FILENAME = "balance_sheets_quarterly.csv"
EXCHANGE_SHORT_NAME = "WSE"  # Warsaw Stock Exchange short name

# %% [markdown]
# ## Useful functions for data fetching

# %%
def fetch_all_symbols():
    url = f"{BASE_URL}/stock/list?apikey={API_KEY}"
    response = requests.get(url)
    data = response.json()
    return data


def filter_wse_symbols(all_symbols):
    wse_symbols = [
        stock["symbol"]
        for stock in all_symbols
        if stock["exchangeShortName"] == EXCHANGE_SHORT_NAME
    ]
    return wse_symbols


def fetch_balance_sheet(symbol):
    url = f"{BASE_URL}/balance-sheet-statement/{symbol}?apikey={API_KEY}&limit={LIMIT}&period={PERIOD}"
    response = requests.get(url)
    data = response.json()
    return data


def fetch_historical_stock_prices(symbol, from_date, to_date):
    # Fetch historical prices for the exact date range of balance sheets
    url = f"{BASE_URL}/historical-price-full/{symbol}?from={from_date}&to={to_date}&apikey={API_KEY}"
    response = requests.get(url)
    data = response.json()
    if "historical" in data:
        return data["historical"]
    return []


def get_closest_price(stock_prices, date):
    # Find the closest stock price to the balance sheet date
    for price_record in stock_prices:
        if price_record["date"] <= date:
            return price_record["close"]
    return None


def create_dataframe(symbols):
    all_data = []

    for symbol in symbols:
        balance_sheet_data = fetch_balance_sheet(symbol)

        if not balance_sheet_data:
            continue

        # Get the earliest and latest dates from the balance sheet data
        balance_sheet_dates = [record["date"] for record in balance_sheet_data]
        from_date = min(balance_sheet_dates)
        to_date = max(balance_sheet_dates)

        # Fetch historical prices for the date range
        stock_prices = fetch_historical_stock_prices(symbol, from_date, to_date)

        for record in balance_sheet_data:
            date = record["date"]
            stock_price = get_closest_price(
                stock_prices, date
            )  # Find the closest price to the balance sheet date
            shares_outstanding = record.get(
                "commonStock", None
            )  # Get the number of shares outstanding

            if stock_price is not None and shares_outstanding is not None:
                # Calculate market cap as stock price * shares outstanding
                market_cap = stock_price * shares_outstanding
            else:
                market_cap = None

            record["symbol"] = symbol
            record["marketCap"] = market_cap
            all_data.append(record)

    df = pd.DataFrame(all_data)
    return df

# %% [markdown]
# ## Fetch data and create a DataFrame

# %%
all_symbols = fetch_all_symbols()
all_symbols
# Out:
# [{'symbol': 'PMGOLD.AX',
#   'name': 'Perth Mint Gold',
#   'price': 17.94,
#   'exchange': 'Australian Securities Exchange',
#   'exchangeShortName': 'ASX',
#   'type': 'etf'},
#  {'symbol': 'CVS',
#   'name': 'CVS Health Corporation',
#   'price': 57.67,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'KVHI',
#   'name': 'KVH Industries, Inc.',
#   'price': 4.615,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'HIMS',
#   'name': 'Hims & Hers Health, Inc.',
#   'price': 14.31,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CMPX',
#   'name': 'Compass Therapeutics, Inc.',
#   'price': 1.5,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'FNF',
#   'name': 'Fidelity National Financial, Inc.',
#   'price': 59.05,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'MGM',
#   'name': 'MGM Resorts International',
#   'price': 36.02,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'EXPE',
#   'name': 'Expedia Group, Inc.',
#   'price': 135.755,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'AXP',
#   'name': 'American Express Company',
#   'price': 251,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'INFY',
#   'name': 'Infosys Limited',
#   'price': 22.98,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'MP',
#   'name': 'MP Materials Corp.',
#   'price': 13.985,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ALKT',
#   'name': 'Alkami Technology, Inc.',
#   'price': 31.17,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'CR.TO',
#   'name': 'Crew Energy Inc.',
#   'price': 6.8,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'DRI',
#   'name': 'Darden Restaurants, Inc.',
#   'price': 158.11,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'STT',
#   'name': 'State Street Corporation',
#   'price': 85.69,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'UBER',
#   'name': 'Uber Technologies, Inc.',
#   'price': 71.21,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'MTZ',
#   'name': 'MasTec, Inc.',
#   'price': 102.16,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'FUN',
#   'name': 'Six Flags Entertainment Corporation',
#   'price': 43.63,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ESTC',
#   'name': 'Elastic N.V.',
#   'price': 73,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'BNS',
#   'name': 'The Bank of Nova Scotia',
#   'price': 50.77,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'COLL',
#   'name': 'Collegium Pharmaceutical, Inc.',
#   'price': 38.13,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'G',
#   'name': 'Genpact Limited',
#   'price': 38.3737,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CELH',
#   'name': 'Celsius Holdings, Inc.',
#   'price': 31.98,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'ON',
#   'name': 'ON Semiconductor Corporation',
#   'price': 71.1,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'RC',
#   'name': 'Ready Capital Corporation',
#   'price': 8.12,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'TOU.TO',
#   'name': 'Tourmaline Oil Corp.',
#   'price': 59.94,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'VSTS',
#   'name': 'Vestis Corporation',
#   'price': 15.57,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'MA',
#   'name': 'Mastercard Incorporated',
#   'price': 475.75,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'AMZN',
#   'name': 'Amazon.com, Inc.',
#   'price': 177.48,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'TSLA',
#   'name': 'Tesla, Inc.',
#   'price': 230.9801,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'MSFT',
#   'name': 'Microsoft Corporation',
#   'price': 408.845,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'PBF',
#   'name': 'PBF Energy Inc.',
#   'price': 32.41,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'MPC',
#   'name': 'Marathon Petroleum Corporation',
#   'price': 170.23,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'NSSC',
#   'name': 'Napco Security Technologies, Inc.',
#   'price': 34.78,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SHC',
#   'name': 'Sotera Health Company',
#   'price': 16.48,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'UNG',
#   'name': 'United States Natural Gas Fund, LP',
#   'price': 14.12,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'VSTA',
#   'name': 'Vasta Platform Limited',
#   'price': 2.55,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'ZTS',
#   'name': 'Zoetis Inc.',
#   'price': 187.4251,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'AMH',
#   'name': 'American Homes 4 Rent',
#   'price': 39.82,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'QSR',
#   'name': 'Restaurant Brands International Inc.',
#   'price': 68.06,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'EOG',
#   'name': 'EOG Resources, Inc.',
#   'price': 122.24,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'AHCO',
#   'name': 'AdaptHealth Corp.',
#   'price': 11.295,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'FTI',
#   'name': 'TechnipFMC plc',
#   'price': 25.16,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CVX',
#   'name': 'Chevron Corporation',
#   'price': 141.32,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'VCLT',
#   'name': 'Vanguard Long-Term Corporate Bond Index Fund',
#   'price': 80.65,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'CLS',
#   'name': 'Celestica Inc.',
#   'price': 45.97,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CRWD',
#   'name': 'CrowdStrike Holdings, Inc.',
#   'price': 257.99,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'AAMC',
#   'name': 'Altisource Asset Management Corporation',
#   'price': 1.6148,
#   'exchange': 'American Stock Exchange',
#   'exchangeShortName': 'AMEX',
#   'type': 'stock'},
#  {'symbol': 'RMBS',
#   'name': 'Rambus Inc.',
#   'price': 40.205,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'TQQQ',
#   'name': 'ProShares UltraPro QQQ',
#   'price': 62.3265,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'SBRA',
#   'name': 'Sabra Health Care REIT, Inc.',
#   'price': 17.46,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SMH',
#   'name': 'VanEck Semiconductor ETF',
#   'price': 225.41,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'NEE',
#   'name': 'NextEra Energy, Inc.',
#   'price': 80.535,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'NCZ',
#   'name': 'Virtus Convertible & Income Fund II',
#   'price': 2.98,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'trust'},
#  {'symbol': 'IMG.TO',
#   'name': 'IAMGOLD Corporation',
#   'price': 6.735,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'APO',
#   'name': 'Apollo Global Management, Inc.',
#   'price': 109.0381,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'BOF',
#   'name': 'BranchOut Food Inc.',
#   'price': 2.9225,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'VZ',
#   'name': 'Verizon Communications Inc.',
#   'price': 41.335,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'HMR.V',
#   'name': 'Homerun Resources Inc.',
#   'price': 1.52,
#   'exchange': 'TSXV',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'EQR',
#   'name': 'Equity Residential',
#   'price': 75.37,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'QLYS',
#   'name': 'Qualys, Inc.',
#   'price': 123.929,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'ATD.TO',
#   'name': 'Alimentation Couche-Tard Inc.',
#   'price': 74.68,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'FSLY',
#   'name': 'Fastly, Inc.',
#   'price': 6.01,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'LUV',
#   'name': 'Southwest Airlines Co.',
#   'price': 30.11,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ELF',
#   'name': 'e.l.f. Beauty, Inc.',
#   'price': 136.88,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'EBR',
#   'name': 'Centrais Elétricas Brasileiras S.A. - Eletrobrás',
#   'price': 7.55,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'NVDD',
#   'name': 'Direxion Daily NVDA Bear 1X Shares',
#   'price': 8.46,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'DLTR',
#   'name': 'Dollar Tree, Inc.',
#   'price': 67.41,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'EMXC',
#   'name': 'iShares MSCI Emerging Markets ex China ETF',
#   'price': 59.68,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'PASG',
#   'name': 'Passage Bio, Inc.',
#   'price': 0.6425,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'TECS',
#   'name': 'Direxion Daily Technology Bear 3X Shares',
#   'price': 6.7935,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'BCS',
#   'name': 'Barclays PLC',
#   'price': 12.079,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CAVA',
#   'name': 'CAVA Group, Inc.',
#   'price': 115.91,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'COST',
#   'name': 'Costco Wholesale Corporation',
#   'price': 881.36,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'FAZ',
#   'name': 'Direxion Daily Financial Bear 3X Shares',
#   'price': 8.19,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'ERAS',
#   'name': 'Erasca, Inc.',
#   'price': 3.005,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'GOVT',
#   'name': 'iShares U.S. Treasury Bond ETF',
#   'price': 23.445,
#   'exchange': 'BATS',
#   'exchangeShortName': 'ETF',
#   'type': 'etf'},
#  {'symbol': 'HUBB',
#   'name': 'Hubbell Incorporated',
#   'price': 368.96,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'IWM',
#   'name': 'iShares Russell 2000 ETF',
#   'price': 212.35,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'JD',
#   'name': 'JD.com, Inc.',
#   'price': 26.44,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'MS',
#   'name': 'Morgan Stanley',
#   'price': 99.895,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'MSTR',
#   'name': 'MicroStrategy Incorporated',
#   'price': 122.36,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'OLLI',
#   'name': "Ollie's Bargain Outlet Holdings, Inc.",
#   'price': 88.21,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SPXL',
#   'name': 'Direxion Daily S&P500 Bull 3X Shares',
#   'price': 145.05,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'STWD',
#   'name': 'Starwood Property Trust, Inc.',
#   'price': 19.975,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'VIK',
#   'name': 'Viking Holdings Ltd',
#   'price': 33.465,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'VRDN',
#   'name': 'Viridian Therapeutics, Inc.',
#   'price': 14.0083,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'XLF',
#   'name': 'Financial Select Sector SPDR\xa0Fund',
#   'price': 45.0099,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'AMD',
#   'name': 'Advanced Micro Devices, Inc.',
#   'price': 140.13,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'VST',
#   'name': 'Vistra Corp.',
#   'price': 76.51,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ATUS',
#   'name': 'Altice USA, Inc.',
#   'price': 2.2,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'BDRY',
#   'name': 'Breakwave Dry Bulk Shipping ETF',
#   'price': 10.745,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'BYD',
#   'name': 'Boyd Gaming Corporation',
#   'price': 59.85,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'IBHD',
#   'name': 'iShares iBonds 2024 Term High Yield and Income ETF',
#   'price': 23.1801,
#   'exchange': 'BATS',
#   'exchangeShortName': 'ETF',
#   'type': 'etf'},
#  {'symbol': 'NWH-UN.TO',
#   'name': 'NorthWest Healthcare Properties Real Estate Investment Trust',
#   'price': 5.075,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'S',
#   'name': 'SentinelOne, Inc.',
#   'price': 23.085,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'DOCS',
#   'name': 'Doximity, Inc.',
#   'price': 35.83,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'FIAT',
#   'name': 'YieldMax Short COIN Option Income Strategy ETF',
#   'price': 22.635,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'ACRV',
#   'name': 'Acrivon Therapeutics, Inc. Common Stock',
#   'price': 7.945,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'TEVA',
#   'name': 'Teva Pharmaceutical Industries Limited',
#   'price': 18.61,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'WBD',
#   'name': 'Warner Bros. Discovery, Inc.',
#   'price': 7.46,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'PDD',
#   'name': 'PDD Holdings Inc.',
#   'price': 91.81,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'MUB',
#   'name': 'iShares National Muni Bond ETF',
#   'price': 107.985,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'ARCH',
#   'name': 'Arch Resources, Inc.',
#   'price': 124.32,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'LTH',
#   'name': 'Life Time Group Holdings, Inc.',
#   'price': 23.59,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'SOUN',
#   'name': 'SoundHound AI, Inc.',
#   'price': 4.45,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'JPST',
#   'name': 'JPMorgan Ultra-Short Income ETF',
#   'price': 50.495,
#   'exchange': 'BATS',
#   'exchangeShortName': 'ETF',
#   'type': 'etf'},
#  {'symbol': 'PSQ',
#   'name': 'ProShares Short QQQ',
#   'price': 42.2785,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'SYK',
#   'name': 'Stryker Corporation',
#   'price': 358.31,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'SPY',
#   'name': 'SPDR S&P 500 ETF Trust',
#   'price': 550.42,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'LC',
#   'name': 'LendingClub Corporation',
#   'price': 11.33,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'FAST',
#   'name': 'Fastenal Company',
#   'price': 64.895,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'F',
#   'name': 'Ford Motor Company',
#   'price': 10.775,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'POW.TO',
#   'name': 'Power Corporation of Canada',
#   'price': 40.99,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'AQN',
#   'name': 'Algonquin Power & Utilities Corp.',
#   'price': 5.29,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'GNLN',
#   'name': 'Greenlane Holdings, Inc.',
#   'price': 5.65,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'HOTH',
#   'name': 'Hoth Therapeutics, Inc.',
#   'price': 1.0667,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'KWEB',
#   'name': 'KraneShares CSI China Internet ETF',
#   'price': 25.51,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'MAT',
#   'name': 'Mattel, Inc.',
#   'price': 18.62,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'MSFL',
#   'name': 'GraniteShares 2x Long MSFT Daily ETF',
#   'price': 22.7789,
#   'exchange': 'Nasdaq',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'PM',
#   'name': 'Philip Morris International Inc.',
#   'price': 125.96,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'SHLS',
#   'name': 'Shoals Technologies Group, Inc.',
#   'price': 5.78,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'TASK',
#   'name': 'TaskUs, Inc.',
#   'price': 13.305,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'AORT',
#   'name': 'Artivion, Inc.',
#   'price': 25.53,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'AMX.V',
#   'name': 'Amex Exploration Inc.',
#   'price': 1.12,
#   'exchange': 'Toronto Stock Exchange Ventures',
#   'exchangeShortName': 'TSXV',
#   'type': 'stock'},
#  {'symbol': 'ANF',
#   'name': 'Abercrombie & Fitch Co.',
#   'price': 137.43,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'PRME',
#   'name': 'Prime Medicine, Inc.',
#   'price': 3.81,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'RMD',
#   'name': 'ResMed Inc.',
#   'price': 245.28,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'AAPL',
#   'name': 'Apple Inc.',
#   'price': 223.62,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'JCI',
#   'name': 'Johnson Controls International plc',
#   'price': 69.8796,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'SMR',
#   'name': 'NuScale Power Corporation',
#   'price': 7.5,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'SOXL',
#   'name': 'Direxion Daily Semiconductor Bull 3X Shares',
#   'price': 30.255,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'EAST',
#   'name': 'Eastside Distilling, Inc.',
#   'price': 2.03,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'EWJ',
#   'name': 'iShares MSCI Japan ETF',
#   'price': 70.47,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'UUUU',
#   'name': 'Energy Fuels Inc.',
#   'price': 4.405,
#   'exchange': 'American Stock Exchange',
#   'exchangeShortName': 'AMEX',
#   'type': 'stock'},
#  {'symbol': 'AVGO',
#   'name': 'Broadcom Inc.',
#   'price': 153.835,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'WEBL',
#   'name': 'Direxion Daily Dow Jones Internet Bull 3X Shares',
#   'price': 15.455,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'CONL',
#   'name': 'GraniteShares ETF Trust - GraniteShares 1.5x Long COIN Daily ETF',
#   'price': 21.3,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'GOOG',
#   'name': 'Alphabet Inc.',
#   'price': 158.86,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'VIXY',
#   'name': 'ProShares VIX Short-Term Futures ETF',
#   'price': 12.97,
#   'exchange': 'BATS',
#   'exchangeShortName': 'ETF',
#   'type': 'etf'},
#  {'symbol': 'QQQ',
#   'name': 'Invesco QQQ Trust',
#   'price': 461.9499,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'NVDA',
#   'name': 'NVIDIA Corporation',
#   'price': 107.4806,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'ACIW',
#   'name': 'ACI Worldwide, Inc.',
#   'price': 49.06,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'JAAA',
#   'name': 'Janus Henderson AAA CLO ETF',
#   'price': 50.67,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'SAIC',
#   'name': 'Science Applications International Corporation',
#   'price': 135.07,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'GTLB',
#   'name': 'GitLab Inc.',
#   'price': 56.4,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SDS',
#   'name': 'ProShares UltraShort S&P500',
#   'price': 22.795,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'AVDV',
#   'name': 'Avantis International Small Cap Value ETF',
#   'price': 67.753,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'BABA',
#   'name': 'Alibaba Group Holding Limited',
#   'price': 82.175,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'BITO',
#   'name': 'ProShares Bitcoin Strategy ETF',
#   'price': 17.1597,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'BIZD',
#   'name': 'VanEck BDC Income ETF',
#   'price': 16.31,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'CWEB',
#   'name': 'Direxion Daily CSI China Internet Bull 2X Shares',
#   'price': 26.21,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'EFR.TO',
#   'name': 'Energy Fuels Inc.',
#   'price': 5.95,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'GASX.V',
#   'name': 'NG Energy International Corp.',
#   'price': 1.03,
#   'exchange': 'Toronto Stock Exchange Ventures',
#   'exchangeShortName': 'TSXV',
#   'type': 'stock'},
#  {'symbol': 'IJR',
#   'name': 'iShares Core S&P Small-Cap ETF',
#   'price': 112.78,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'INTC',
#   'name': 'Intel Corporation',
#   'price': 19.575,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'MRK',
#   'name': 'Merck & Co., Inc.',
#   'price': 119.425,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ORCL',
#   'name': 'Oracle Corporation',
#   'price': 142.3,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'OXY',
#   'name': 'Occidental Petroleum Corporation',
#   'price': 53.82,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'PWSC',
#   'name': 'PowerSchool Holdings, Inc.',
#   'price': 22.73,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'SCHH',
#   'name': 'Schwab U.S. REIT ETF',
#   'price': 22.6398,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'SOXS',
#   'name': 'Direxion Daily Semiconductor Bear 3X Shares',
#   'price': 26.86,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'UTZ',
#   'name': 'Utz Brands, Inc.',
#   'price': 17.65,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'XOM',
#   'name': 'Exxon Mobil Corporation',
#   'price': 113.68,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'AIDX.TO',
#   'name': 'Healwell AI Inc.',
#   'price': 1.63,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'ADVM',
#   'name': 'Adverum Biotechnologies, Inc.',
#   'price': 6.78,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'GOOGL',
#   'name': 'Alphabet Inc.',
#   'price': 157.495,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'RTX',
#   'name': 'RTX Corporation',
#   'price': 119.595,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'DLTH',
#   'name': 'Duluth Holdings Inc.',
#   'price': 3.76,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SG',
#   'name': 'Sweetgreen, Inc.',
#   'price': 27.83,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'TCOM',
#   'name': 'Trip.com Group Limited',
#   'price': 47.96,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'EFV',
#   'name': 'iShares MSCI EAFE Value ETF',
#   'price': 56.455,
#   'exchange': 'BATS',
#   'exchangeShortName': 'ETF',
#   'type': 'etf'},
#  {'symbol': 'SCHK',
#   'name': 'Schwab 1000 Index ETF',
#   'price': 52.96,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'LSCC',
#   'name': 'Lattice Semiconductor Corporation',
#   'price': 43.27,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SWKS',
#   'name': 'Skyworks Solutions, Inc.',
#   'price': 102.1,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SEE',
#   'name': 'Sealed Air Corporation',
#   'price': 34.405,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'NATR',
#   'name': "Nature's Sunshine Products, Inc.",
#   'price': 13.66,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'JTAI',
#   'name': 'Jet.AI Inc.',
#   'price': 0.13,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'ULS',
#   'name': 'UL Solutions Inc.',
#   'price': 50.48,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'YMAB',
#   'name': 'Y-mAbs Therapeutics, Inc.',
#   'price': 14.07,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'IART',
#   'name': 'Integra LifeSciences Holdings Corporation',
#   'price': 19.29,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'HAL',
#   'name': 'Halliburton Company',
#   'price': 29.16,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'PYPL',
#   'name': 'PayPal Holdings, Inc.',
#   'price': 72.43,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'ASTE',
#   'name': 'Astec Industries, Inc.',
#   'price': 30.98,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'AUTL',
#   'name': 'Autolus Therapeutics plc',
#   'price': 4.285,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'DKNG',
#   'name': 'DraftKings Inc.',
#   'price': 35.28,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'FTNT',
#   'name': 'Fortinet, Inc.',
#   'price': 75.71,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'MU',
#   'name': 'Micron Technology, Inc.',
#   'price': 90.36,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'NIO',
#   'name': 'NIO Inc.',
#   'price': 4.7236,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'OMF',
#   'name': 'OneMain Holdings, Inc.',
#   'price': 47.57,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'PLTR',
#   'name': 'Palantir Technologies Inc.',
#   'price': 30.2981,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'RY.TO',
#   'name': 'Royal Bank of Canada',
#   'price': 164.25,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'SHYD',
#   'name': 'VanEck Short High Yield Muni ETF',
#   'price': 22.52,
#   'exchange': 'BATS',
#   'exchangeShortName': 'ETF',
#   'type': 'etf'},
#  {'symbol': 'SON',
#   'name': 'Sonoco Products Company',
#   'price': 54.895,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'TGT',
#   'name': 'Target Corporation',
#   'price': 151.535,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'TNA',
#   'name': 'Direxion Daily Small Cap Bull 3X Shares',
#   'price': 39.58,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'VTWO',
#   'name': 'Vanguard Russell 2000 Index Fund',
#   'price': 85.895,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'XLU',
#   'name': 'Utilities Select Sector SPDR\xa0Fund',
#   'price': 76.7097,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'ALTM',
#   'name': 'Arcadium Lithium plc',
#   'price': 2.405,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'APH',
#   'name': 'Amphenol Corporation',
#   'price': 61.77,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'WEST',
#   'name': 'Westrock Coffee Company, LLC',
#   'price': 8.5,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'RITM',
#   'name': 'Rithm Capital Corp.',
#   'price': 11.57,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'AC.TO',
#   'name': 'Air Canada',
#   'price': 15.485,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'SSP',
#   'name': 'The E.W. Scripps Company',
#   'price': 1.875,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SN',
#   'name': 'SharkNinja, Inc.',
#   'price': 98.0225,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'DDOG',
#   'name': 'Datadog, Inc.',
#   'price': 110.14,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'AFRM',
#   'name': 'Affirm Holdings, Inc.',
#   'price': 40.62,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'FE',
#   'name': 'FirstEnergy Corp.',
#   'price': 44.52,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'OLED',
#   'name': 'Universal Display Corporation',
#   'price': 189.39,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'RR',
#   'name': 'Richtech Robotics Inc. Class B Common Stock',
#   'price': 1.17,
#   'exchange': 'NASDAQ',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'PLUG',
#   'name': 'Plug Power Inc.',
#   'price': 1.745,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'FRO',
#   'name': 'Frontline Ltd.',
#   'price': 22.32,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'INFN',
#   'name': 'Infinera Corporation',
#   'price': 6.24,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'BAX',
#   'name': 'Baxter International Inc.',
#   'price': 38.6,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'C',
#   'name': 'Citigroup Inc.',
#   'price': 60.67,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'GM',
#   'name': 'General Motors Company',
#   'price': 48.16,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'HOOD',
#   'name': 'Robinhood Markets, Inc.',
#   'price': 19.195,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'MWA',
#   'name': 'Mueller Water Products, Inc.',
#   'price': 19.95,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'SMPL',
#   'name': 'The Simply Good Foods Company',
#   'price': 33.44,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'UVXY',
#   'name': 'ProShares Ultra VIX Short-Term Futures ETF',
#   'price': 27.4,
#   'exchange': 'BATS',
#   'exchangeShortName': 'ETF',
#   'type': 'etf'},
#  {'symbol': 'WISA',
#   'name': 'WiSA Technologies, Inc.',
#   'price': 2.52,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'XOP',
#   'name': 'SPDR\xa0S&P\xa0Oil & Gas Exploration & Production ETF',
#   'price': 131.6,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'VKTX',
#   'name': 'Viking Therapeutics, Inc.',
#   'price': 55.65,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'VLTO',
#   'name': 'Veralto Corporation',
#   'price': 109.88,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'WMT',
#   'name': 'Walmart Inc.',
#   'price': 76.975,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'SOXX',
#   'name': 'iShares Semiconductor ETF',
#   'price': 214.14,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'SO',
#   'name': 'The Southern Company',
#   'price': 89.31,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'BMA',
#   'name': 'Banco Macro S.A.',
#   'price': 63.745,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'TARA',
#   'name': 'Protara Therapeutics, Inc.',
#   'price': 1.955,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'TMF',
#   'name': 'Direxion Daily 20+ Year Treasury Bull 3X Shares',
#   'price': 61.22,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'ALLO',
#   'name': 'Allogene Therapeutics, Inc.',
#   'price': 2.52,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'TEM',
#   'name': 'Tempus AI, Inc. Class A Common Stock',
#   'price': 54.7,
#   'exchange': 'Nasdaq',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'IJH',
#   'name': 'iShares Core S&P Mid-Cap ETF',
#   'price': 59.845,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'CAT',
#   'name': 'Caterpillar Inc.',
#   'price': 334.03,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CCL',
#   'name': 'Carnival Corporation & plc',
#   'price': 16.24,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CNK',
#   'name': 'Cinemark Holdings, Inc.',
#   'price': 28.425,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ESGE',
#   'name': 'iShares ESG Aware MSCI EM ETF',
#   'price': 33.835,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'ETH',
#   'name': 'Ethan Allen Interiors Inc.',
#   'price': 2.255,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'FHN',
#   'name': 'First Horizon Corporation',
#   'price': 15.695,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'LKQ',
#   'name': 'LKQ Corporation',
#   'price': 40.5,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'MRVL',
#   'name': 'Marvell Technology, Inc.',
#   'price': 70.99,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'PEY.TO',
#   'name': 'Peyto Exploration & Development Corp.',
#   'price': 14.05,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'PTON',
#   'name': 'Peloton Interactive, Inc.',
#   'price': 4.935,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'UA',
#   'name': 'Under Armour, Inc.',
#   'price': 7.63,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'DOCU',
#   'name': 'DocuSign, Inc.',
#   'price': 57.04,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'VXX',
#   'name': 'iPath Series B S&P 500 VIX Short-Term Futures ETN',
#   'price': 52.475,
#   'exchange': 'BATS',
#   'exchangeShortName': 'ETF',
#   'type': 'etf'},
#  {'symbol': 'WBS',
#   'name': 'Webster Financial Corporation',
#   'price': 45.03,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ATNM',
#   'name': 'Actinium Pharmaceuticals, Inc.',
#   'price': 1.735,
#   'exchange': 'American Stock Exchange',
#   'exchangeShortName': 'AMEX',
#   'type': 'stock'},
#  {'symbol': 'FTSM',
#   'name': 'First Trust Enhanced Short Maturity ETF',
#   'price': 59.895,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'DCTH',
#   'name': 'Delcath Systems, Inc.',
#   'price': 10.58,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'BK',
#   'name': 'The Bank of New York Mellon Corporation',
#   'price': 68,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ST',
#   'name': 'Sensata Technologies Holding plc',
#   'price': 36.3,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'MNST',
#   'name': 'Monster Beverage Corporation',
#   'price': 48.325,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'PR',
#   'name': 'Permian Resources Corporation',
#   'price': 13.5,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'O',
#   'name': 'Realty Income Corporation',
#   'price': 62.455,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'NCLH',
#   'name': 'Norwegian Cruise Line Holdings Ltd.',
#   'price': 17.215,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'DIA',
#   'name': 'SPDR Dow Jones Industrial Average ETF Trust',
#   'price': 408.9,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'IEMG',
#   'name': 'iShares Core MSCI Emerging Markets ETF',
#   'price': 53.525,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'STX',
#   'name': 'Seagate Technology Holdings plc',
#   'price': 101.014,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'TD.TO',
#   'name': 'The Toronto-Dominion Bank',
#   'price': 82.03,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'WHLR',
#   'name': 'Wheeler Real Estate Investment Trust, Inc.',
#   'price': 5.202,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'USB',
#   'name': 'U.S. Bancorp',
#   'price': 45.72,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CMS',
#   'name': 'CMS Energy Corporation',
#   'price': 68.215,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'FWRD',
#   'name': 'Forward Air Corporation',
#   'price': 32.905,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'CGNX',
#   'name': 'Cognex Corporation',
#   'price': 38.93,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'GBCI',
#   'name': 'Glacier Bancorp, Inc.',
#   'price': 44.4,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'LLY',
#   'name': 'Eli Lilly and Company',
#   'price': 915.66,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'NVO',
#   'name': 'Novo Nordisk A/S',
#   'price': 131.36,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'OXLC',
#   'name': 'Oxford Lane Capital Corp.',
#   'price': 5.3563,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'ROIV',
#   'name': 'Roivant Sciences Ltd.',
#   'price': 12.095,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SPXU',
#   'name': 'ProShares UltraPro Short S&P500',
#   'price': 28.01,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'SQQQ',
#   'name': 'ProShares UltraPro Short QQQ',
#   'price': 8.9465,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'DX',
#   'name': 'Dynex Capital, Inc.',
#   'price': 12.485,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CRDF',
#   'name': 'Cardiff Oncology, Inc.',
#   'price': 2.2,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'RIG',
#   'name': 'Transocean Ltd.',
#   'price': 4.16,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'WBA',
#   'name': 'Walgreens Boots Alliance, Inc.',
#   'price': 8.82,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'UMH',
#   'name': 'UMH Properties, Inc.',
#   'price': 19.775,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'AES',
#   'name': 'The AES Corporation',
#   'price': 16.995,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CTS',
#   'name': 'CTS Corporation',
#   'price': 46.3,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'BNRG',
#   'name': 'Brenmiller Energy Ltd',
#   'price': 1.1108,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'APDN',
#   'name': 'Applied DNA Sciences, Inc.',
#   'price': 1.3661,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'FXY',
#   'name': 'Invesco CurrencyShares Japanese Yen Trust',
#   'price': 64.48,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'IRDM',
#   'name': 'Iridium Communications Inc.',
#   'price': 27.86,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'AEP',
#   'name': 'American Electric Power Company, Inc.',
#   'price': 102.85,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'BN',
#   'name': 'Brookfield Corporation',
#   'price': 47.57,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CUZ',
#   'name': 'Cousins Properties Incorporated',
#   'price': 28.49,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'DIS',
#   'name': 'The Walt Disney Company',
# ...
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'BEKE',
#   'name': 'KE Holdings Inc.',
#   'price': 14.845,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CDNS',
#   'name': 'Cadence Design Systems, Inc.',
#   'price': 252.075,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'HCI',
#   'name': 'HCI Group, Inc.',
#   'price': 99.055,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'LIDR',
#   'name': 'AEye, Inc.',
#   'price': 1.095,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'MCS',
#   'name': 'The Marcus Corporation',
#   'price': 14.51,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'MLGO',
#   'name': 'MicroAlgo Inc.',
#   'price': 0.3645,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'OKTA',
#   'name': 'Okta, Inc.',
#   'price': 75.35,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'PCRX',
#   'name': 'Pacira BioSciences, Inc.',
#   'price': 14.89,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SLV',
#   'name': 'iShares Silver Trust',
#   'price': 26.245,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'WES',
#   'name': 'Western Midstream Partners, LP',
#   'price': 37.68,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'YEXT',
#   'name': 'Yext, Inc.',
#   'price': 5.58,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'LPAAW',
#   'name': 'Launch One Acquisition Corp.',
#   'price': 0.08,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'HLX',
#   'name': 'Helix Energy Solutions Group, Inc.',
#   'price': 10.085,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ZI',
#   'name': 'ZoomInfo Technologies Inc.',
#   'price': 9.91,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'BBUS',
#   'name': 'JPMorgan BetaBuilders U.S. Equity ETF',
#   'price': 99.31,
#   'exchange': 'BATS',
#   'exchangeShortName': 'ETF',
#   'type': 'etf'},
#  {'symbol': 'DNN',
#   'name': 'Denison Mines Corp.',
#   'price': 1.525,
#   'exchange': 'American Stock Exchange',
#   'exchangeShortName': 'AMEX',
#   'type': 'stock'},
#  {'symbol': 'OKE',
#   'name': 'ONEOK, Inc.',
#   'price': 91.98,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'UNIT',
#   'name': 'Uniti Group Inc.',
#   'price': 5.385,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'Z',
#   'name': 'Zillow Group, Inc. Class C',
#   'price': 54.49,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'CNSP',
#   'name': 'CNS Pharmaceuticals, Inc.',
#   'price': 0.1546,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'T.TO',
#   'name': 'TELUS Corporation',
#   'price': 22.815,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'EL',
#   'name': 'The Estée Lauder Companies Inc.',
#   'price': 90.65,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ELAN',
#   'name': 'Elanco Animal Health Incorporated',
#   'price': 15.425,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ESI',
#   'name': 'Element Solutions Inc',
#   'price': 25.765,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'EWZ',
#   'name': 'iShares MSCI Brazil ETF',
#   'price': 29.835,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'CMPS',
#   'name': 'COMPASS Pathways plc',
#   'price': 6.74,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'DBD',
#   'name': 'Diebold Nixdorf, Incorporated',
#   'price': 42.12,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'IAG.TO',
#   'name': 'iA Financial Corporation Inc.',
#   'price': 104.91,
#   'exchange': 'Toronto Stock Exchange',
#   'exchangeShortName': 'TSX',
#   'type': 'stock'},
#  {'symbol': 'JOBY',
#   'name': 'Joby Aviation, Inc.',
#   'price': 4.87,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'KEY-PL',
#   'name': 'KeyCorp',
#   'price': 24.09,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'SH',
#   'name': 'ProShares Short S&P500',
#   'price': 11.42,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'SVRA',
#   'name': 'Savara Inc.',
#   'price': 4.52,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'VYM',
#   'name': 'Vanguard High Dividend Yield Index Fund',
#   'price': 125.0684,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'AVTE',
#   'name': 'Aerovate Therapeutics, Inc.',
#   'price': 1.91,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'GWRE',
#   'name': 'Guidewire Software, Inc.',
#   'price': 143.75,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'VOD',
#   'name': 'Vodafone Group Public Limited Company',
#   'price': 10.225,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'ACI',
#   'name': 'Albertsons Companies, Inc.',
#   'price': 18.815,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'URG',
#   'name': 'Ur-Energy Inc.',
#   'price': 1.08,
#   'exchange': 'American Stock Exchange',
#   'exchangeShortName': 'AMEX',
#   'type': 'stock'},
#  {'symbol': 'PWM',
#   'name': 'Prestige Wealth Inc.',
#   'price': 0.74,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'LINC',
#   'name': 'Lincoln Educational Services Corporation',
#   'price': 11.71,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'HES',
#   'name': 'Hess Corporation',
#   'price': 129.61,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'BDX',
#   'name': 'Becton, Dickinson and Company',
#   'price': 235.145,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'BLUE',
#   'name': 'bluebird bio, Inc.',
#   'price': 0.5657,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'BPMC',
#   'name': 'Blueprint Medicines Corporation',
#   'price': 91.3,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'CYBR',
#   'name': 'CyberArk Software Ltd.',
#   'price': 270.24,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'RGNX',
#   'name': 'REGENXBIO Inc.',
#   'price': 11.21,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SLRN',
#   'name': 'Acelyrin, Inc.',
#   'price': 4.625,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SMCX',
#   'name': 'Defiance Daily Target 2X Long SMCI ETF',
#   'price': 8.18,
#   'exchange': 'Nasdaq',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'WT',
#   'name': 'WisdomTree, Inc.',
#   'price': 9.5,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'SCVL',
#   'name': 'Shoe Carnival, Inc.',
#   'price': 40.9101,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'STLA',
#   'name': 'Stellantis N.V.',
#   'price': 15.875,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'MRSN',
#   'name': 'Mersana Therapeutics, Inc.',
#   'price': 1.445,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'DT',
#   'name': 'Dynatrace, Inc.',
#   'price': 49.58,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'FBLG',
#   'name': 'FibroBiologics, Inc. Common Stock',
#   'price': 1.75,
#   'exchange': 'Nasdaq',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'REI',
#   'name': 'Ring Energy, Inc.',
#   'price': 1.6443,
#   'exchange': 'American Stock Exchange',
#   'exchangeShortName': 'AMEX',
#   'type': 'stock'},
#  {'symbol': 'SABR',
#   'name': 'Sabre Corporation',
#   'price': 2.915,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'CATO',
#   'name': 'The Cato Corporation',
#   'price': 4.81,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CBRL',
#   'name': 'Cracker Barrel Old Country Store, Inc.',
#   'price': 37.93,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'DOW',
#   'name': 'Dow Inc.',
#   'price': 51.439,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'GFS',
#   'name': 'GLOBALFOUNDRIES Inc.',
#   'price': 41.63,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'KBR',
#   'name': 'KBR, Inc.',
#   'price': 66.775,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ODFL',
#   'name': 'Old Dominion Freight Line, Inc.',
#   'price': 184.825,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'OLPX',
#   'name': 'Olaplex Holdings, Inc.',
#   'price': 2.295,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'PHAT',
#   'name': 'Phathom Pharmaceuticals, Inc.',
#   'price': 17.78,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'PIII',
#   'name': 'P3 Health Partners Inc.',
#   'price': 0.4867,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SQ',
#   'name': 'Block, Inc.',
#   'price': 64.5603,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'TBBK',
#   'name': 'The Bancorp, Inc.',
#   'price': 49.5,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'TPX',
#   'name': 'Tempur Sealy International, Inc.',
#   'price': 50.2,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'TSDD',
#   'name': 'GraniteShares 1.5x Short TSLA Daily ETF',
#   'price': 8.84,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'etf'},
#  {'symbol': 'WOLF',
#   'name': 'Wolfspeed, Inc.',
#   'price': 8.74,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'EBS',
#   'name': 'Emergent BioSolutions Inc.',
#   'price': 7.9,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'HLT',
#   'name': 'Hilton Worldwide Holdings Inc.',
#   'price': 215.62,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ARCC',
#   'name': 'Ares Capital Corporation',
#   'price': 20.835,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'CYRX',
#   'name': 'Cryoport, Inc.',
#   'price': 8.32,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'AUR',
#   'name': 'Aurora Innovation, Inc.',
#   'price': 4.115,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'CCCS',
#   'name': 'CCC Intelligent Solutions Holdings Inc.',
#   'price': 10.595,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CHPT',
#   'name': 'ChargePoint Holdings, Inc.',
#   'price': 1.395,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'EVLV',
#   'name': 'Evolv Technologies Holdings, Inc.',
#   'price': 3.77,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'INSW',
#   'name': 'International Seaways, Inc.',
#   'price': 49.64,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'IONS',
#   'name': 'Ionis Pharmaceuticals, Inc.',
#   'price': 47.93,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'NULG',
#   'name': 'Nuveen ESG Large-Cap Growth ETF',
#   'price': 78.059,
#   'exchange': 'BATS',
#   'exchangeShortName': 'ETF',
#   'type': 'etf'},
#  {'symbol': 'SAP',
#   'name': 'SAP SE',
#   'price': 213.15,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'ALFUW',
#   'name': 'Centurion Acquisition Corp.',
#   'price': 0.12,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'GSAT',
#   'name': 'Globalstar, Inc.',
#   'price': 1.28,
#   'exchange': 'American Stock Exchange',
#   'exchangeShortName': 'AMEX',
#   'type': 'stock'},
#  {'symbol': 'FPE',
#   'name': 'First Trust Preferred Securities and Income ETF',
#   'price': 17.895,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  {'symbol': 'ADI',
#   'name': 'Analog Devices, Inc.',
#   'price': 220.415,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'CLDX',
#   'name': 'Celldex Therapeutics, Inc.',
#   'price': 43.595,
#   'exchange': 'NASDAQ Capital Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'MNKD',
#   'name': 'MannKind Corporation',
#   'price': 6.065,
#   'exchange': 'NASDAQ Global Market',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'SGMO',
#   'name': 'Sangamo Therapeutics, Inc.',
#   'price': 0.7498,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'CPRI',
#   'name': 'Capri Holdings Limited',
#   'price': 35.225,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'AEE',
#   'name': 'Ameren Corporation',
#   'price': 83.905,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'CSIQ',
#   'name': 'Canadian Solar Inc.',
#   'price': 12.6271,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'symbol': 'CP',
#   'name': 'Canadian Pacific Railway Limited',
#   'price': 83.68,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'DV',
#   'name': 'DoubleVerify Holdings, Inc.',
#   'price': 19.175,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'DTM',
#   'name': 'DT Midstream, Inc.',
#   'price': 76.33,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'symbol': 'EWS',
#   'name': 'iShares MSCI Singapore ETF',
#   'price': 20.805,
#   'exchange': 'New York Stock Exchange Arca',
#   'exchangeShortName': 'AMEX',
#   'type': 'etf'},
#  ...]

# %%
wse_symbols = filter_wse_symbols(all_symbols)
wse_symbols
# Out:
# ['PKP.WA',
#  'KGH.WA',
#  'NTC.WA',
#  'PZU.WA',
#  'PCO.WA',
#  'ELT.WA',
#  'DBC.WA',
#  'JSW.WA',
#  'CPS.WA',
#  'PUR.WA',
#  'ATT.WA',
#  'ECH.WA',
#  'GMT.WA',
#  'ALR.WA',
#  'MIL.WA',
#  'TEN.WA',
#  'QRS.WA',
#  'BDX.WA',
#  'ENA.WA',
#  'LPP.WA',
#  'MRB.WA',
#  'DNP.WA',
#  'LBW.WA',
#  'SNK.WA',
#  'MRC.WA',
#  'XTB.WA',
#  'SVE.WA',
#  '11B.WA',
#  'RPC.WA',
#  'ETFBCASH.WA',
#  'ETFBW20ST.WA',
#  'ETFBSPXPL.WA',
#  'ETFBW20LV.WA',
#  'DOM.WA',
#  'GEA.WA',
#  'ACT.WA',
#  'ALL.WA',
#  'ENG.WA',
#  'SHO.WA',
#  'BRS.WA',
#  'PKN.WA',
#  'CLN.WA',
#  'NNG.WA',
#  'PEO.WA',
#  'CLC.WA',
#  'GRX.WA',
#  'WLT.WA',
#  'APR.WA',
#  'SIM.WA',
#  'RNK.WA',
#  'PXM.WA',
#  'MBK.WA',
#  'CDR.WA',
#  'RFK.WA',
#  'AMB.WA',
#  'MSZ.WA',
#  'VRC.WA',
#  'EUR.WA',
#  'CRJ.WA',
#  'GPP.WA',
#  'CAR.WA',
#  'CRI.WA',
#  'IBS.WA',
#  'MBR.WA',
#  'UNT.WA',
#  'PEP.WA',
#  'VRG.WA',
#  'CLE.WA',
#  'DBE.WA',
#  'GRN.WA',
#  'APN.WA',
#  'BDZ.WA',
#  'BIO.WA',
#  'BBD.WA',
#  'BCS.WA',
#  'FON.WA',
#  'KGL.WA',
#  'KGN.WA',
#  'KPL.WA',
#  'OPN.WA',
#  'PLW.WA',
#  'SNX.WA',
#  'ULG.WA',
#  'AMC.WA',
#  'OTS.WA',
#  'ART.WA',
#  'IZO.WA',
#  'CTX.WA',
#  'ATR.WA',
#  'GOP.WA',
#  'DAD.WA',
#  'CMP.WA',
#  'FRO.WA',
#  'CRM.WA',
#  'ING.WA',
#  'WTN.WA',
#  'DCR.WA',
#  'KER.WA',
#  'MAB.WA',
#  'MOV.WA',
#  'PCE.WA',
#  'PCX.WA',
#  'PEN.WA',
#  'PRT.WA',
#  'RDN.WA',
#  'STF.WA',
#  'TOR.WA',
#  'UNI.WA',
#  'URT.WA',
#  'ABS.WA',
#  'GPW.WA',
#  'ZEP.WA',
#  'JWW.WA',
#  'MCI.WA',
#  'MDG.WA',
#  'DEK.WA',
#  'VOT.WA',
#  'WXF.WA',
#  'BOS.WA',
#  'ALI.WA',
#  'NWG.WA',
#  'STX.WA',
#  '1AT.WA',
#  'NVA.WA',
#  'VOX.WA',
#  'ERB.WA',
#  'RAE.WA',
#  'GTC.WA',
#  'RWL.WA',
#  'APT.WA',
#  'ATD.WA',
#  'ENT.WA',
#  'LTX.WA',
#  'MAK.WA',
#  'MOC.WA',
#  'MON.WA',
#  'PBX.WA',
#  'PJP.WA',
#  'SCP.WA',
#  'WIK.WA',
#  'ZAP.WA',
#  'FMG.WA',
#  'MXC.WA',
#  'ENE.WA',
#  'EAT.WA',
#  'GTN.WA',
#  'TRK.WA',
#  'PTG.WA',
#  'BCX.WA',
#  'AAT.WA',
#  'PCR.WA',
#  'ASB.WA',
#  'ASE.WA',
#  'AST.WA',
#  'BMC.WA',
#  'BMX.WA',
#  'COG.WA',
#  'DAT.WA',
#  'EAH.WA',
#  'KCH.WA',
#  'MLS.WA',
#  'NTT.WA',
#  'NVG.WA',
#  'OND.WA',
#  'PLZ.WA',
#  'SNW.WA',
#  'TOA.WA',
#  'ZUE.WA',
#  'ZMT.WA',
#  'ANR.WA',
#  'BFT.WA',
#  'ALE.WA',
#  'SPL.WA',
#  'TPE.WA',
#  'KTY.WA',
#  'RBW.WA',
#  'ABE.WA',
#  'PGE.WA',
#  'HUG.WA',
#  'TXT.WA',
#  'ACP.WA',
#  'NEU.WA',
#  'CBF.WA',
#  'CIG.WA',
#  'BNP.WA',
#  'KRU.WA',
#  'WPL.WA',
#  'DVL.WA',
#  'SNT.WA',
#  'PKO.WA',
#  'BHW.WA',
#  'CCC.WA',
#  'LWB.WA',
#  'SLV.WA',
#  'ATC.WA',
#  'OPL.WA',
#  'HRP.WA',
#  'ETFBM40TR.WA',
#  'SPR.WA',
#  'ETFBTBSP.WA',
#  'ICE.WA',
#  'ETFBW20TR.WA',
#  'XTP.WA',
#  'MEX.WA',
#  'DIG.WA',
#  'MDI.WA',
#  'KOM.WA',
#  '06N.WA',
#  'SEK.WA',
#  'PHN.WA',
#  'GIG.WA',
#  'FEE.WA',
#  'ETFBS80TR.WA',
#  'GIF.WA',
#  'ETFSP500.WA',
#  'ETFBNDXPL.WA',
#  'DEL.WA',
#  'IMS.WA',
#  'IFI.WA',
#  'MOL.WA',
#  'BLO.WA',
#  'TAR.WA',
#  'BBT.WA',
#  'SFS.WA',
#  'BOW.WA',
#  'MNC.WA',
#  'DPL.WA',
#  'CAV.WA',
#  'MCR.WA',
#  'LKD.WA',
#  'ENI.WA',
#  'ALG.WA',
#  'SKH.WA',
#  'APE.WA',
#  'PAT.WA',
#  'INL.WA',
#  'ETL.WA',
#  'IZS.WA',
#  'MUR.WA',
#  'IPE.WA',
#  '3RG.WA',
#  'VVD.WA',
#  'SGN.WA',
#  'EKP.WA',
#  'LBT.WA',
#  'SEL.WA',
#  'GKI.WA',
#  'PGV.WA',
#  'TOW.WA',
#  'HEL.WA',
#  'ACG.WA',
#  'IPO.WA',
#  'STP.WA',
#  'ADV.WA',
#  'AWM.WA',
#  'WWL.WA',
#  'PMP.WA',
#  'B24.WA',
#  'VGO.WA',
#  'ATP.WA',
#  'CMR.WA',
#  'PHR.WA',
#  'CPR.WA',
#  'RVU.WA',
#  'DGE.WA',
#  'BMW.WA',
#  'WAS.WA',
#  'PAS.WA',
#  'ODL.WA',
#  'ETFDAX.WA',
#  'SPH.WA',
#  'TSG.WA',
#  'TLX.WA',
#  'ATG.WA',
#  'ATS.WA',
#  'CEZ.WA',
#  'RLP.WA',
#  'ITB.WA',
#  'FAB.WA',
#  'LEN.WA',
#  'ARH.WA',
#  'INK.WA',
#  'BCM.WA',
#  'ZRE.WA',
#  'MSW.WA',
#  'EDI.WA',
#  'CDL.WA',
#  'GOB.WA',
#  'HRS.WA',
#  'SON.WA',
#  'ALV.WA',
#  'KMP.WA',
#  'PCF.WA',
#  'MIR.WA',
#  'RES.WA',
#  'ETCGLDRMAU.WA',
#  'MLK.WA',
#  'BST.WA',
#  'TBL.WA',
#  'KRK.WA',
#  'MVP.WA',
#  'FSG.WA',
#  'CCE.WA',
#  'SHD.WA',
#  'EFK.WA',
#  'CPA.WA',
#  'TRI.WA',
#  'PBF.WA',
#  'CZT.WA',
#  'AGO.WA',
#  'BIP.WA',
#  'EHG.WA',
#  'STS.WA',
#  'FTE.WA',
#  'RND.WA',
#  'HDR.WA',
#  'LES.WA',
#  'VIN.WA',
#  'AGT.WA',
#  'PGM.WA',
#  'MFO.WA',
#  'EUC.WA',
#  'SKA.WA',
#  'KCI.WA',
#  'PWX.WA',
#  'OPG.WA',
#  'SAN.WA',
#  'LRQ.WA',
#  'LSI.WA',
#  'XPL.WA',
#  'OTM.WA',
#  'KVT.WA',
#  'NTU.WA',
#  'SFG.WA',
#  'PRM.WA',
#  'KSG.WA',
#  'CLD.WA',
#  'MGT.WA',
#  'OPM.WA',
#  'IMC.WA',
#  'ONO.WA',
#  'MLG.WA',
#  'MSP.WA',
#  'IDM.WA',
#  'YRL.WA',
#  'FER.WA',
#  'CSR.WA',
#  'QNT.WA',
#  'RMK.WA',
#  'PPS.WA',
#  'JMT.WA',
#  'UCG.WA',
#  'TRN.WA',
#  'INP.WA',
#  'NXG.WA',
#  'SKL.WA',
#  'ULM.WA',
#  'INC.WA',
#  'KRI.WA',
#  'EMC.WA',
#  'SEN.WA',
#  'CFI.WA',
#  'NVT.WA',
#  'SVRS.WA',
#  'ZUK.WA',
#  'LAB.WA',
#  'DGA.WA',
#  'DTR.WA',
#  'IIA.WA',
#  'MZA.WA',
#  'VOW.WA',
#  'KPD.WA',
#  'ITX.WA',
#  'CPD.WA',
#  'PBG.WA',
#  'IZB.WA',
#  'THG.WA',
#  'BAY.WA',
#  'SWG.WA',
#  'MAN.WA',
#  'HMI.WA',
#  'MOJ.WA',
#  'OBL.WA',
#  'PRI.WA',
#  'WIS.WA',
#  'MWT.WA',
#  'ZAL.WA',
#  'SHG.WA',
#  'TRR.WA',
#  'CTS.WA',
#  'APL.WA',
#  'PSHE.WA',
#  'MBG.WA',
#  'ERG.WA',
#  'RAF.WA',
#  'MBW.WA',
#  'ENP.WA',
#  'CPL.WA',
#  '08N.WA',
#  'TMR.WA',
#  'RNC.WA',
#  'OVO.WA',
#  'RHD.WA',
#  'OEX.WA',
#  'PSW.WA',
#  'BKM.WA',
#  'GCN.WA',
#  'INV.WA',
#  'FMF.WA',
#  'HUGE.WA',
#  'SUW.WA',
#  'KRC.WA',
#  'PUE.WA',
#  'BRG.WA',
#  'ARR.WA',
#  'GBK.WA',
#  'VTI.WA',
#  'K2H.WA',
#  'PUN.WA',
#  'GNB.WA',
#  'LTS.WA',
#  'IMP.WA',
#  'SKT.WA',
#  'ATL.WA',
#  'ITM.WA',
#  'FFI.WA',
#  'PGN.WA',
#  'WOJ.WA',
#  'CPG.WA',
#  'VTL.WA',
#  'PMA.WA',
#  'U2K.WA',
#  'URS.WA',
#  'ZWC.WA',
#  'OPF.WA',
#  'BAH.WA',
#  'BRA.WA',
#  'STH.WA',
#  'IFR.WA',
#  'TIM.WA',
#  'CNT.WA',
#  'LVC.WA',
#  'SOL.WA',
#  'EEX.WA',
#  'ASM.WA',
#  'SES.WA',
#  'CIE.WA',
#  'GLC.WA',
#  'PTH.WA',
#  'SLZ.WA',
#  'ELZ.WA',
#  'EST.WA',
#  'ASML.WA',
#  'RWE.WA',
#  'BML.WA',
#  'AML.WA',
#  'R22.WA']

# %%
df = create_dataframe(wse_symbols)

# %%
df.head()
# Out:
#          date  symbol reportedCurrency         cik fillingDate  \
# 0  2024-03-31  PKP.WA              PLN  0000000000  2024-03-31
# 1  2023-12-31  PKP.WA              PLN  0000000000  2023-12-31
# 2  2023-09-30  PKP.WA              PLN  0000000000  2023-09-30
# 3  2023-06-30  PKP.WA              PLN  0000000000  2023-06-30
# 4  2023-03-31  PKP.WA              PLN  0000000000  2023-03-31
#
#           acceptedDate calendarYear period  cashAndCashEquivalents  \
# 0  2024-03-29 20:00:00         2024     Q1             176600000.0
# 1  2023-12-30 19:00:00         2023     Q4             226200000.0
# 2  2023-09-29 20:00:00         2023     Q3             216800000.0
# 3  2023-06-29 20:00:00         2023     Q2             174600000.0
# 4  2023-03-30 20:00:00         2023     Q1             230300000.0
#
#    shortTermInvestments  ...   totalEquity  \
# 0                   0.0  ...  3.064900e+09
# 1           -10100000.0  ...  3.202500e+09
# 2           -16900000.0  ...  3.286400e+09
# 3           -16900000.0  ...  3.303200e+09
# 4           -16300000.0  ...  3.357600e+09
#
#    totalLiabilitiesAndStockholdersEquity  minorityInterest  \
# 0                           8.250300e+09               0.0
# 1                           8.320000e+09               0.0
# 2                           8.290200e+09               0.0
# 3                           8.107900e+09               0.0
# 4                           8.048000e+09               0.0
#
#    totalLiabilitiesAndTotalEquity  totalInvestments     totalDebt  \
# 0                    8.250300e+09        51500000.0  2.895400e+09
# 1                    8.320000e+09        42700000.0  2.893800e+09
# 2                    8.290200e+09        41100000.0  2.653000e+09
# 3                    8.107900e+09        40500000.0  2.650400e+09
# 4                    8.048000e+09        42700000.0  2.675800e+09
#
#         netDebt  link  finalLink     marketCap
# 0  2.718800e+09                   2.929004e+10
# 1  2.667600e+09                   3.264899e+10
# 2  2.436200e+09                   3.296250e+10
# 3  2.475800e+09                   3.842639e+10
# 4  2.445500e+09                   3.585119e+10
#
# [5 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20360 entries, 0 to 20359
# Data columns (total 55 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   date                                     20360 non-null  object
#  1   symbol                                   20360 non-null  object
#  2   reportedCurrency                         20360 non-null  object
#  3   cik                                      20360 non-null  object
#  4   fillingDate                              20360 non-null  object
#  5   acceptedDate                             20128 non-null  object
#  6   calendarYear                             20360 non-null  object
#  7   period                                   20360 non-null  object
#  8   cashAndCashEquivalents                   20360 non-null  float64
#  9   shortTermInvestments                     20360 non-null  float64
#  10  cashAndShortTermInvestments              20360 non-null  float64
#  11  netReceivables                           20360 non-null  float64
#  12  inventory                                20360 non-null  float64
#  13  otherCurrentAssets                       20360 non-null  float64
#  14  totalCurrentAssets                       20360 non-null  float64
#  15  propertyPlantEquipmentNet                20360 non-null  float64
#  16  goodwill                                 20360 non-null  float64
#  17  intangibleAssets                         20360 non-null  float64
#  18  goodwillAndIntangibleAssets              20360 non-null  float64
#  19  longTermInvestments                      20360 non-null  float64
#  20  taxAssets                                20360 non-null  float64
#  21  otherNonCurrentAssets                    20360 non-null  float64
#  22  totalNonCurrentAssets                    20360 non-null  float64
#  23  otherAssets                              20360 non-null  float64
#  24  totalAssets                              20360 non-null  float64
#  25  accountPayables                          20360 non-null  float64
#  26  shortTermDebt                            20360 non-null  float64
#  27  taxPayables                              20360 non-null  float64
#  28  deferredRevenue                          20360 non-null  float64
#  29  otherCurrentLiabilities                  20360 non-null  float64
#  30  totalCurrentLiabilities                  20360 non-null  float64
#  31  longTermDebt                             20360 non-null  float64
#  32  deferredRevenueNonCurrent                20360 non-null  float64
#  33  deferredTaxLiabilitiesNonCurrent         20360 non-null  float64
#  34  otherNonCurrentLiabilities               20360 non-null  float64
#  35  totalNonCurrentLiabilities               20360 non-null  float64
#  36  otherLiabilities                         20360 non-null  float64
#  37  capitalLeaseObligations                  20360 non-null  float64
#  38  totalLiabilities                         20360 non-null  float64
#  39  preferredStock                           20360 non-null  float64
#  40  commonStock                              20360 non-null  float64
#  41  retainedEarnings                         20360 non-null  float64
#  42  accumulatedOtherComprehensiveIncomeLoss  20360 non-null  float64
#  43  othertotalStockholdersEquity             20360 non-null  float64
#  44  totalStockholdersEquity                  20360 non-null  float64
#  45  totalEquity                              20360 non-null  float64
#  46  totalLiabilitiesAndStockholdersEquity    20360 non-null  float64
#  47  minorityInterest                         20360 non-null  float64
#  48  totalLiabilitiesAndTotalEquity           20360 non-null  float64
#  49  totalInvestments                         20360 non-null  float64
#  50  totalDebt                                20360 non-null  float64
#  51  netDebt                                  20360 non-null  float64
#  52  link                                     20360 non-null  object
#  53  finalLink                                20360 non-null  object
#  54  marketCap                                18585 non-null  float64
# dtypes: float64(45), object(10)
# memory usage: 8.5+ MB

# %%
# Ensure the output directory exists
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# Save DataFrame to a CSV file in the output directory
output_path = os.path.join(OUTPUT_DIR, OUTPUT_FILENAME)
df.to_csv(output_path, index=False)

print(f"Data has been saved to {output_path}")
# Out:
# Data has been saved to data\balance_sheets_quarterly.csv
